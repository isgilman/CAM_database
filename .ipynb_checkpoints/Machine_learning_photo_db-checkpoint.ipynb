# %% [markdown]
# # Machine learning with the photosynthesis database
# This began as an exlporation of morphological data associated with CAM in 163 bromeliad species ([Males 2018](http://www.publish.csiro.au/FP/FP17071)), but has snowballed into a [dataset of photosynthesis-associated morphological and physiological measurements](https://github.com/isgilman/photo_db) with a small accompanying package called `photo_db` which allows users to access the database and do a few simple, useful manipulations to the data. Below I'll walk through importing the data, visualizing it with a few features of `photo_db`, and then show how these data can be used to classify a plant's photosynthetic pathway using morphological data.
#
# I originally thought to apply machine learning techniques (specifically linear classifiers like support vector machines and random forests) to the bromeliad data because scatter plots of the raw data seemed to show clear break between C3 and CAM species, but projecting the data into PC space eroded these patterns. Below I show that the most extreme phenotypes&mdash;C3 and CAM&mdash;are relatively easily classified in bromeliads using only the following morphological measurements:
#
# * chlorenchyma cell diameter
# * chlorenchyma vertical thickness
# * leaf thickness
# * hydrenchyma vertical thickness
# * air channel area.
#
# Although this is a big success, these morphological measurements are about as easy to collect as $\delta C^{13}$ isotope measurements that we already know can distinguish these phenotypes. The real challege is to use morphology to classify C3-CAM species, which may or may not show the hallmark isotope signature of CAM species. The bromeliad data do not contain enough instances of these phenotypes for classification, so I turn to a study of 173 orchid species ([Silvera et al. 2005](http://www.publish.csiro.au/FP/FP04179)) that spans the CAM-spectrum with relatively equal abundances. Unfortunately, these data only contain three morphological features and the small size means that each category has about half of the observations as in the bromeliad data, so our power to discriminate between them is reduced.
#
# I will be (hopefully) constantly refining and adding analyses as I find more data or better ways to handle it. My largest problem right now is the sparsity of the CAM database matrix. Currently I'm working on different ways to impute missing data, which is what `photo_db` grew out of.
#
# **References**
# 1. Males J. 2018. Concerted anatomical change associated with crassulacean acid metabolism in the Bromeliaceae. Functional Plant Biol. 45:681–695.
# 2. Silvera K., Santiago L.S., Winter K. 2005. Distribution of crassulacean acid metabolism in orchids of Panama: evidence of selection for weak and strong modes. Functional Plant Biol. 32:397–11.

# %%
# photo_db
from photo_db import photo_db

# Core
import pandas as pd
import scipy as sp
import numpy as np
# Plotting
# %matplotlib inline
import missingno as msno
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
sns.set(style="ticks")
# Machine learning
import sklearn as skl
from sklearn import svm, datasets
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_predict, cross_val_score

# %% [markdown]
# ## Load data using `photo_db`
# Loading the data is easy with `pull_data`. There are two sets of data that we can access:
#  1. 'cam_db', which contains the morphological and physiological data, along with taxonomic metadata
#  2. 'the_list', which contains the known photosynthetic pathways for all land plant genera

# %%
# Load data from GitHub
cam_db = photo_db.pull_data()
cam_db.head()
# Out:
#         Family       Subfamily       Tribe     Subtribe      Genus  \
# 0  Orchidaceae             NaN         NaN          NaN    Acineta
# 1  Orchidaceae  Epidendroideae  Cymbidieae   Oncidiinae        Ada
# 2  Orchidaceae             NaN         NaN          NaN  Ancipitia
# 3  Orchidaceae  Epidendroideae  Arethuseae  Arethusinae   Arundina
# 4  Orchidaceae  Epidendroideae  Cymbidieae   Oncidiinae    Aspasia
#
#          Species Subspecies  BS_area_um2  FM_DM  FM_DM_sd  \
# 0            sp.        NaN          NaN    7.1       0.3
# 1        allenii        NaN          NaN    8.1       0.5
# 2  crocodiliceps        NaN          NaN    8.7       0.9
# 3   graminifolia        NaN          NaN    3.5       0.2
# 4  epidendroides        NaN          NaN    5.3       0.2
#
#            ...            avg_elevation_m  LCCDM  SLAFM  tissue  \
# 0          ...                        NaN    NaN    NaN     NaN
# 1          ...                        NaN    NaN    NaN     NaN
# 2          ...                        NaN    NaN    NaN     NaN
# 3          ...                        NaN    NaN    NaN     NaN
# 4          ...                        NaN    NaN    NaN     NaN
#
#                  long_name  pct_night_C02  H+_ev_mumol_g-1_DW  \
# 0              Acineta sp.            NaN                 NaN
# 1              Ada allenii            NaN                 NaN
# 2  Ancipitia crocodiliceps            NaN                 NaN
# 3    Arundina graminifolia            NaN                 NaN
# 4    Aspasia epidendroides            NaN                 NaN
#
#   H+_ev_mumol_g-1_DW_sd  H+_mo_mumol_g-1_DW  H+_mo_mumol_g-1_DW_sd
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                   NaN                 NaN                    NaN
# 3                   NaN                 NaN                    NaN
# 4                   NaN                 NaN                    NaN
#
# [5 rows x 56 columns]

# %% [markdown]
# `photo_db` also contains some useful summary statistics and plotting methods.

# %%
photo_db.db_info(cam_db)
# Out:
# The CAM database consists of:
# 	5856 observations,
# 	59 families,
# 	12 subfamiles,
# 	13 tribes,
# 	22 subtribes,
# 	447 genera, and
# 	3762 species from 61 publications.
# 0.828 of the data matrix is missing and
# 785 observations have known photosynthetic pathways.

# %% [markdown]
# Using `drop_ambig`, we can reduce this matrix to only those accessions with recognized genera and species. We'll also remove measurements from tissue other than leaves.

# %%
# Drop unidentified species and genera
cam_db = photo_db.drop_ambig(cam_db, rank='Species')
cam_db = photo_db.drop_ambig(cam_db, rank='Genus')
# Drop nonleaf and stem measurements
drop_tissues = ['bract', 'flower', 'fruit wall', 'inflorescence axis','pedicel']
cam_db = cam_db[~cam_db['Tissue'].isin(drop_tissues)]
cam_db = cam_db[~cam_db['plant_part'].isin(drop_tissues)]
cam_db = cam_db[~cam_db['tissue'].isin(drop_tissues)]
cam_db.drop(labels=['Tissue', 'plant_part', 'tissue'], axis=1, inplace=True)

# %% [markdown]
# Now we'll use the `db_info` function to get a broad picture of our data, which incorpates missing dat plotting from the `missingno` package.

# %%
photo_db.db_info(cam_db=cam_db, plt_missingdata=True, labels=True, fontsize=12)
# Out:
# The CAM database consists of:
# 	5452 observations,
# 	57 families,
# 	12 subfamiles,
# 	13 tribes,
# 	22 subtribes,
# 	433 genera, and
# 	3549 species from 61 publications.
# 0.823 of the data matrix is missing and
# 760 observations have known photosynthetic pathways.

# %% [markdown]
# Using the missingno module we can visualize the missing data in our dataframe. Black represents measurements and white is the lack of. The squiggly line on the far right shows how many features have measurements for any one observations, which here ranges from 6 (strictly taxonomic information plus a single measurement) to 21 (taxonomy plus many measurements).
#
# Now we'll look at an example of what we can do with these data, beginning with some visualization of the data and ended with classification of species into different types of photosynthesis using purely morphological measurements.

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(12,6))

ax0.hist(x=cam_db[cam_db['Pathway']=='CAM']['dC13'].dropna(), edgecolor='blue',
         linewidth=2, color='blue', alpha=0.5, bins=15)
ax0.hist(x=cam_db[cam_db['Pathway']=='C3']['dC13'].dropna(), edgecolor='orange', 
         linewidth=2, color='orange', alpha=0.5, bins=15)
ax0.hist(x=cam_db[cam_db['Pathway']=='C3-CAM']['dC13'].dropna(), edgecolor='red', 
         linewidth=2, color='red', alpha=0.5, bins=10)
ax0.hist(x=cam_db[cam_db['Pathway']=='C4']['dC13'].dropna(), edgecolor='green', 
         linewidth=2, color='green', alpha=0.5, bins=10)

ax1.hist(x=cam_db[cam_db['Pathway'].isin(['C3', 'C4', 'CAM', 'C3-CAM', 'C3-C4'])]['dC13'].dropna(), 
         fc=(1, 1, 1, 1), edgecolor='black', linewidth=2, alpha=1, bins=25)
ax1.hist(x=cam_db[cam_db['Pathway'].isnull()]['dC13'].dropna(), color='grey', alpha=0.25, bins=50)

orange_patch = mpatches.Patch(color='orange', alpha=0.5, label='C3', )
green_patch = mpatches.Patch(color='green', alpha=0.5, label='C4')
red_patch = mpatches.Patch(color='red', alpha=0.5, label='C3-CAM')
blue_patch = mpatches.Patch(color='blue', alpha=0.5, label='CAM')

ax0.legend(handles=[orange_patch, green_patch, red_patch, blue_patch], fontsize=12, frameon=True, )
ax0.set_xlim([-40, -5])
ax0.set_xlabel('$\delta$C$^{13}$', size=16)

grey_patch = mpatches.Patch(color='grey', alpha=0.5, label='Unknown pathway')
black_patch = mpatches.Patch(facecolor='white', edgecolor='black', linewidth=1, label='Known pathway')

ax1.legend(handles=[grey_patch, black_patch], fontsize=12, frameon=True, )
ax1.set_xlim([-40, -5])
ax1.set_xlabel('$\delta$C$^{13}$', size=16)

# plt.savefig('/Users/iangilman/GitHub/photo_db/images/dC13_hist.pdf', format='pdf', transparent=True, dpi=300);

# %% [markdown]
# In the carbon isotope histograms above we see both the characteristic bimodal distribution that separates C3 and CAM, and that the majority of measurements don't have a pathway listed. We can impute data based on information from closely related taxa by using the `data_fill_modes` function. Although Pandas provides a bunch of different ways to fill missing data (e.g. first, last, average), it does not offer a mode method, which we need to impute categorical values. Below we'll first impute the mode of `cam_db['Pathway]` for each species, and then each genus, where those data are missig from observations and able to be filled.

# %%
filled = photo_db.fill_na_modes(df=cam_db, group_by='Species', to_fill=['Pathway'])
filled = photo_db.fill_na_modes(df=filled, group_by='Genus', to_fill=['Pathway'])
photo_db.db_info(filled)
# Out:
# The CAM database consists of:
# 	5452 observations,
# 	57 families,
# 	12 subfamiles,
# 	13 tribes,
# 	22 subtribes,
# 	433 genera, and
# 	3549 species from 61 publications.
# 0.815 of the data matrix is missing and
# 3268 observations have known photosynthetic pathways.

# %% [markdown]
# We've now increased the number of photosynthetic pathways known (mostly from apply the modes of genera to species within) by about 5x.

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(12,6))

ax0.hist(x=filled[filled['Pathway']=='CAM']['dC13'].dropna(), edgecolor='blue',
         linewidth=2, color='blue', alpha=0.5, bins=40)
ax0.hist(x=filled[filled['Pathway']=='C3']['dC13'].dropna(), edgecolor='orange', 
         linewidth=2, color='orange', alpha=0.5, bins=30)
ax0.hist(x=filled[filled['Pathway']=='C3-CAM']['dC13'].dropna(), edgecolor='red', 
         linewidth=2, color='red', alpha=0.5, bins=20)
ax0.hist(x=filled[filled['Pathway']=='C4']['dC13'].dropna(), edgecolor='green', 
         linewidth=2, color='green', alpha=0.5, bins=10)

ax1.hist(x=filled[filled['Pathway'].isin(['C3', 'C4', 'CAM', 'C3-CAM', 'C3-C4'])]['dC13'].dropna(), 
         fc=(1, 1, 1, 1), edgecolor='black', linewidth=2, alpha=1, bins=25)
ax1.hist(x=filled[filled['Pathway'].isnull()]['dC13'].dropna(), color='grey', alpha=0.25, bins=50)

orange_patch = mpatches.Patch(color='orange', alpha=0.5, label='C3', )
green_patch = mpatches.Patch(color='green', alpha=0.5, label='C4')
red_patch = mpatches.Patch(color='red', alpha=0.5, label='C3-CAM')
blue_patch = mpatches.Patch(color='blue', alpha=0.5, label='CAM')

ax0.legend(handles=[orange_patch, green_patch, red_patch, blue_patch], fontsize=12, frameon=True, )
ax0.set_xlim([-40, -5])
ax0.set_xlabel('$\delta$C$^{13}$', size=14)

grey_patch = mpatches.Patch(color='grey', alpha=0.5, label='Unknown pathway')
black_patch = mpatches.Patch(facecolor='white', edgecolor='black', linewidth=1, label='Known pathway')

ax1.legend(handles=[grey_patch, black_patch], fontsize=12, frameon=True, )
ax1.set_xlim([-40, -5])
ax1.set_xlabel('$\delta$C$^{13}$', size=14);

# %% [markdown]
# Our known pathways now dwarf our unknown, but the data don't seem to make much sense now as we have a lot of "CAM" taxa less negative than -22, and vice versa with C3 taxa. This is because of the bias in records in the original database. Because the original database is biased towards CAM taxa, there are many genera who's only observation comes from a one, or a few, CAM taxa. This means that all other observations within that genus will be labeled as "CAM" simply because it is the only measurements we have. Let's inspect some of these weird observations.

# %%
drop_odd = filled.loc[~((filled['Pathway']=='CAM') & (filled['dC13']<-22))]

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(12,6))

ax0.hist(x=drop_odd[drop_odd['Pathway']=='CAM']['dC13'].dropna(), edgecolor='blue',
         linewidth=2, color='blue', alpha=0.5, bins=40)
ax0.hist(x=drop_odd[drop_odd['Pathway']=='C3']['dC13'].dropna(), edgecolor='orange', 
         linewidth=2, color='orange', alpha=0.5, bins=30)
ax0.hist(x=drop_odd[drop_odd['Pathway']=='C3-CAM']['dC13'].dropna(), edgecolor='red', 
         linewidth=2, color='red', alpha=0.5, bins=20)
ax0.hist(x=drop_odd[drop_odd['Pathway']=='C4']['dC13'].dropna(), edgecolor='green', 
         linewidth=2, color='green', alpha=0.5, bins=10)

ax1.hist(x=drop_odd[drop_odd['Pathway'].isin(['C3', 'C4', 'CAM', 'C3-CAM', 'C3-C4'])]['dC13'].dropna(), 
         fc=(1, 1, 1, 1), edgecolor='black', linewidth=2, alpha=1, bins=25)
ax1.hist(x=drop_odd[drop_odd['Pathway'].isnull()]['dC13'].dropna(), color='grey', alpha=0.25, bins=50)

orange_patch = mpatches.Patch(color='orange', alpha=0.5, label='C3', )
green_patch = mpatches.Patch(color='green', alpha=0.5, label='C4')
red_patch = mpatches.Patch(color='red', alpha=0.5, label='C3-CAM')
blue_patch = mpatches.Patch(color='blue', alpha=0.5, label='CAM')

ax0.legend(handles=[orange_patch, green_patch, red_patch, blue_patch], fontsize=12, frameon=True, loc='upper left')
ax0.set_xlim([-40, -5])
ax0.set_xlabel('$\delta$C$^{13}$', size=16)

grey_patch = mpatches.Patch(color='grey', alpha=0.5, label='Unknown pathway')
black_patch = mpatches.Patch(facecolor='white', edgecolor='black', linewidth=1, label='Known pathway')

ax1.legend(handles=[grey_patch, black_patch], fontsize=12, frameon=True, loc='upper left')
ax1.set_xlim([-40, -5])
ax1.set_xlabel('$\delta$C$^{13}$', size=16)

# plt.savefig('/Users/iangilman/GitHub/photo_db/images/dC13_hist_imputed.pdf', format='pdf', transparent=True, dpi=300);

# %%
fill_avg = photo_db.fill_numeric(df=drop_odd, group_by='Genus', to_fill=['leaf_thickness_um', "FM_DM"])

# %%
photo_db.db_info(fill_avg, plt_missingdata=True, labels=True)
# Out:
# The CAM database consists of:
# 	4873 observations,
# 	57 families,
# 	12 subfamiles,
# 	13 tribes,
# 	22 subtribes,
# 	433 genera, and
# 	3043 species from 61 publications.
# 0.8 of the data matrix is missing and
# 2689 observations have known photosynthetic pathways.

# %%
fig, (ax, ax1) = plt.subplots(1,2, figsize=(12,6), sharey=True)

ax.scatter(x=fill_avg.loc[fill_avg['Pathway']=='CAM']['leaf_thickness_um'], 
           y=fill_avg.loc[fill_avg['Pathway']=='CAM']['dC13'], marker='o', alpha=0.34, c='blue')
ax.scatter(x=fill_avg.loc[fill_avg['Pathway']=='C3']['leaf_thickness_um'], 
           y=fill_avg.loc[fill_avg['Pathway']=='C3']['dC13'], marker='o', alpha=0.34, c='orange')
ax.scatter(x=fill_avg.loc[fill_avg['Pathway']=='C3-CAM']['leaf_thickness_um'], 
           y=fill_avg.loc[fill_avg['Pathway']=='C3-CAM']['dC13'], marker='o', alpha=0.34, c='red')
ax.scatter(x=fill_avg.loc[fill_avg['Pathway']=='C4']['leaf_thickness_um'], 
           y=fill_avg.loc[fill_avg['Pathway']=='C4']['dC13'], marker='o', alpha=0.34, c='green')

ax1.scatter(x=fill_avg.loc[fill_avg['Pathway']=='CAM']['FM_DM'], 
           y=fill_avg.loc[fill_avg['Pathway']=='CAM']['dC13'], marker='o', alpha=0.34, c='blue')
ax1.scatter(x=fill_avg.loc[fill_avg['Pathway']=='C3']['FM_DM'], 
           y=fill_avg.loc[fill_avg['Pathway']=='C3']['dC13'], marker='o', alpha=0.34, c='orange')
ax1.scatter(x=fill_avg.loc[fill_avg['Pathway']=='C3-CAM']['FM_DM'], 
           y=fill_avg.loc[fill_avg['Pathway']=='C3-CAM']['dC13'], marker='o', alpha=0.34, c='red')
ax1.scatter(x=fill_avg.loc[fill_avg['Pathway']=='C4']['FM_DM'], 
           y=fill_avg.loc[fill_avg['Pathway']=='C4']['dC13'], marker='o', alpha=0.34, c='green')

ax.set_xscale('log')
ax1.set_xscale('log')
ax1.set_xlim([-0.1, 20])

ax.set_xlabel('$log$(leaf thickness) ($\mu$m)', size=16)
ax1.set_xlabel('$log$(FM:DM)', size=16)

ax.set_ylabel('$\delta$C$^{13}$', size=16)

orange_patch = mpatches.Patch(color='orange', alpha=0.75, label='C3', )
green_patch = mpatches.Patch(color='green', alpha=0.75, label='C4')
red_patch = mpatches.Patch(color='red', alpha=0.75, label='C3-CAM')
blue_patch = mpatches.Patch(color='blue', alpha=0.75, label='CAM')

ax.legend(handles=[orange_patch, green_patch, red_patch, blue_patch], fontsize=12, frameon=True);

# %% [markdown]
# ## "The List", expanded
# "The List" refers to the ever-growing list of genera that contain CAM lineages&mdash;compiled by Dr. Andrew Smith, Dr. Joe Holtum, and Dr. Klaus Winter. I have expanded it with _every_ instance of a noted photosynthetic pathway that I can find. Most of the C4 designations came from Dr. Rowan Sage's recent acticle with a [list of C4 lineages](https://academic.oup.com/jxb/article/67/14/4039/2197596) (Sage 2016).

# %%
thelist = photo_db.pull_data('the_list')
thelist.head()
# Out:
#         Family        Genus  C3  CAM  C3-CAM  C4-CAM  C4  C3-C4 Sources Order  \
# 0  Orchidaceae           Aa NaN  NaN     NaN     NaN NaN    NaN     NaN   NaN
# 1   Asteraceae  Aaronsohnia NaN  NaN     NaN     NaN NaN    NaN     NaN   NaN
# 2     Fabaceae      Abacosa NaN  NaN     NaN     NaN NaN    NaN     NaN   NaN
# 3     Fabaceae      Abarema NaN  NaN     NaN     NaN NaN    NaN     NaN   NaN
# 4   Asteraceae     Abasoloa NaN  NaN     NaN     NaN NaN    NaN     NaN   NaN
#
#    Subfamily  Tribe  Subtribe
# 0        NaN    NaN       NaN
# 1        NaN    NaN       NaN
# 2        NaN    NaN       NaN
# 3        NaN    NaN       NaN
# 4        NaN    NaN       NaN

# %%
thelist = thelist.drop(['Subfamily', 'Tribe', 'Subtribe', 'Sources', 'Order'], axis=1)

# %%
print len(thelist)
thelist.describe()
# Out:
# 20917
#                 C3          CAM       C3-CAM       C4-CAM           C4  \
# count  1475.000000  1475.000000  1475.000000  1475.000000  1475.000000
# mean      0.442712     0.304407     0.014915     0.000678     0.274576
# std       0.496876     0.460312     0.121255     0.026038     0.446452
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       1.000000     1.000000     0.000000     0.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#             C3-C4
# count  888.000000
# mean     0.013514
# std      0.115525
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %% [markdown]
# The list is a bunch of binary indicators for each type of photosynthesis. We cant see that we have roughly 21,000 genera, but only about 1,500 of these have identified pathways.

# %%
thelist.set_index('Family', inplace=True)
thelist.head()
# Out:
#                    Genus  C3  CAM  C3-CAM  C4-CAM  C4  C3-C4
# Family
# Orchidaceae           Aa NaN  NaN     NaN     NaN NaN    NaN
# Asteraceae   Aaronsohnia NaN  NaN     NaN     NaN NaN    NaN
# Fabaceae         Abacosa NaN  NaN     NaN     NaN NaN    NaN
# Fabaceae         Abarema NaN  NaN     NaN     NaN NaN    NaN
# Asteraceae      Abasoloa NaN  NaN     NaN     NaN NaN    NaN

# %%
test = photo_db.pull_data('the_list').drop(['Family','Subfamily', 'Tribe', 'Subtribe', 'Sources', 'Order'], axis=1)
test.head()
# Out:
#          Genus  C3  CAM  C3-CAM  C4-CAM  C4  C3-C4
# 0           Aa NaN  NaN     NaN     NaN NaN    NaN
# 1  Aaronsohnia NaN  NaN     NaN     NaN NaN    NaN
# 2      Abacosa NaN  NaN     NaN     NaN NaN    NaN
# 3      Abarema NaN  NaN     NaN     NaN NaN    NaN
# 4     Abasoloa NaN  NaN     NaN     NaN NaN    NaN

# %%
test.set_index("Genus", inplace=True)
test.head()
# Out:
#              C3  CAM  C3-CAM  C4-CAM  C4  C3-C4
# Genus
# Aa          NaN  NaN     NaN     NaN NaN    NaN
# Aaronsohnia NaN  NaN     NaN     NaN NaN    NaN
# Abacosa     NaN  NaN     NaN     NaN NaN    NaN
# Abarema     NaN  NaN     NaN     NaN NaN    NaN
# Abasoloa    NaN  NaN     NaN     NaN NaN    NaN

# %%
test.dropna(how='all', inplace=True)

# %%
pdb = photo_db.pull_data()[['Family', 'Genus', 'Species', 'Subspecies', 'long_name', 'Pathway', 'dC13']]
photo_db.db_info(pdb)
pdb.head()
# Out:
# The CAM database consists of:
# 	5856 observations,
# 	59 families,
# 	None subfamiles,
# 	None tribes,
# 	None subtribes,
# 	447 genera, and
# 	3762 species from None publications.
# 0.304 of the data matrix is missing and
# 785 observations have known photosynthetic pathways.
#         Family      Genus        Species Subspecies                long_name  \
# 0  Orchidaceae    Acineta            sp.        NaN              Acineta sp.
# 1  Orchidaceae        Ada        allenii        NaN              Ada allenii
# 2  Orchidaceae  Ancipitia  crocodiliceps        NaN  Ancipitia crocodiliceps
# 3  Orchidaceae   Arundina   graminifolia        NaN    Arundina graminifolia
# 4  Orchidaceae    Aspasia  epidendroides        NaN    Aspasia epidendroides
#
#   Pathway  dC13
# 0      C3 -28.1
# 1      C3 -28.2
# 2      C3 -28.3
# 3      C3 -26.5
# 4  C3-CAM -27.9

# %%
photo_db.check_nan(pdb.iloc[0]["Subspecies"])
# Out:
# True

# %%
for index, row in pdb.iterrows():
    genus = row["Genus"]
    pwy = row["Pathway"]
    if photo_db.check_nan(pwy):
        print("{} is missing a pathway".format(genus))
        if genus in test.index:
            listpwys = list(test.loc[genus][test.loc[genus]>0].index)
            print(">>>Found pathway(s) for {}: {}".format(genus, listpwys))
            
            if len(listpwys)>1 and not photo_db.check_nan(row["dC13"]):
                if row["dC13"]<-22.0:
                    # Remove CAM and C4 if dC13 is very negative
                    listpwys = list(set(listpwys)-set(['CAM', 'C4']))
                    print("\tSome data: {}, {}, {}". format(genus, listpwys, row["dC13"]))
                elif row["dC13"]>-20.0:
                    # Remove C3 if dC13 is very positive
                    listpwys = list(set(listpwys)-set(['C3']))
                    print("\tSome data: {}, {}, {}". format(genus, listpwys, row["dC13"]))
            else:
                newpwy = listpwys[0]
# Out:
# Gongora is missing a pathway
# Trichocentrum is missing a pathway
# >>>Found pathway(s) for Trichocentrum: ['CAM']
# Ronnbergia is missing a pathway
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -27.29
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -14.37
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -14.88
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -15.28
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -13.73
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -15.1
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -25.66
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -32.03
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -28.6
# Vanda is missing a pathway
# >>>Found pathway(s) for Vanda: ['CAM']
# Dischidia is missing a pathway
# >>>Found pathway(s) for Dischidia: ['CAM']
# Agrostophyllum is missing a pathway
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -24.3
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -23.26
# Epicranthes is missing a pathway
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['CAM'], -12.25
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['CAM'], -13.9
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['CAM'], -13.05
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -34.01
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -31.2
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -31.82
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -31.5
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -32.6
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -28.01
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -31.02
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -28.84
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -32.26
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -28.23
# Ceratostylis is missing a pathway
# Ceratostylis is missing a pathway
# Ceratostylis is missing a pathway
# Ceratostylis is missing a pathway
# Ceratostylis is missing a pathway
# Ceratostylis is missing a pathway
# Ceratostylis is missing a pathway
# Ceratostylis is missing a pathway
# Ceratostylis is missing a pathway
# Ceratostylis is missing a pathway
# Ceratostylis is missing a pathway
# Ceratostylis is missing a pathway
# Cryptostylis is missing a pathway
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -30.25
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -12.49
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -13.0
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -24.44
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -28.08
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -29.36
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -31.49
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -28.06
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -28.47
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -29.85
# Dipodium is missing a pathway
# Eria is missing a pathway
# >>>Found pathway(s) for Eria: ['C3', 'CAM']
# 	Some data: Eria, ['C3'], -31.17
# Eria is missing a pathway
# >>>Found pathway(s) for Eria: ['C3', 'CAM']
# 	Some data: Eria, ['C3'], -31.09
# Eria is missing a pathway
# >>>Found pathway(s) for Eria: ['C3', 'CAM']
# 	Some data: Eria, ['C3'], -30.22
# Grammatophyllum is missing a pathway
# Robiquetia is missing a pathway
# >>>Found pathway(s) for Robiquetia: ['CAM']
# Agrostophyllum is missing a pathway
# Coelogyne is missing a pathway
# >>>Found pathway(s) for Coelogyne: ['CAM']
# Coelogyne is missing a pathway
# >>>Found pathway(s) for Coelogyne: ['CAM']
# Dendrochilum is missing a pathway
# Diplocaulobium is missing a pathway
# Flickingeria is missing a pathway
# >>>Found pathway(s) for Flickingeria: ['CAM']
# Glomera is missing a pathway
# Glossorhyncha is missing a pathway
# Glossorhyncha is missing a pathway
# Glossorhyncha is missing a pathway
# Glossorhyncha is missing a pathway
# Glossorhyncha is missing a pathway
# Glossorhyncha is missing a pathway
# Glossorhyncha is missing a pathway
# Liparis is missing a pathway
# Liparis is missing a pathway
# Liparis is missing a pathway
# Luisia is missing a pathway
# >>>Found pathway(s) for Luisia: ['CAM']
# Luisia is missing a pathway
# >>>Found pathway(s) for Luisia: ['CAM']
# Pedilochilus is missing a pathway
# Pedilochilus is missing a pathway
# Pedilochilus is missing a pathway
# Pedilochilus is missing a pathway
# Phreatia is missing a pathway
# Phreatia is missing a pathway
# Phreatia is missing a pathway
# Phreatia is missing a pathway
# Phreatia is missing a pathway
# Phreatia is missing a pathway
# Phreatia is missing a pathway
# Phreatia is missing a pathway
# Phreatia is missing a pathway
# Saccolabium is missing a pathway
# >>>Found pathway(s) for Saccolabium: ['CAM']
# Loxogramme is missing a pathway
# Loxogramme is missing a pathway
# Belvisia is missing a pathway
# Belvisia is missing a pathway
# Belvisia is missing a pathway
# Belvisia is missing a pathway
# Belvisia is missing a pathway
# Microsorium is missing a pathway
# Selliguea is missing a pathway
# Selliguea is missing a pathway
# Calanthe is missing a pathway
# >>>Found pathway(s) for Calanthe: ['CAM']
# Calanthe is missing a pathway
# >>>Found pathway(s) for Calanthe: ['CAM']
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -34.66
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -30.61
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -26.8
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -30.58
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -28.93
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -25.52
# Diplocaulobium is missing a pathway
# Epiblastus is missing a pathway
# Epiblastus is missing a pathway
# Epiblastus is missing a pathway
# Epiblastus is missing a pathway
# Epiblastus is missing a pathway
# Epiblastus is missing a pathway
# Glomera is missing a pathway
# Liparis is missing a pathway
# Mediocalcar is missing a pathway
# Mediocalcar is missing a pathway
# Mediocalcar is missing a pathway
# Oberonia is missing a pathway
# >>>Found pathway(s) for Oberonia: ['CAM']
# Oberonia is missing a pathway
# >>>Found pathway(s) for Oberonia: ['CAM']
# Octarrhena is missing a pathway
# Octarrhena is missing a pathway
# Octarrhena is missing a pathway
# Prosaptia is missing a pathway
# Libbertia is missing a pathway
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -26.18
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -29.72
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -31.86
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -30.52
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -28.98
# Liparis is missing a pathway
# Pterostylis is missing a pathway
# >>>Found pathway(s) for Pterostylis: ['C3']
# Thelymitra is missing a pathway
# >>>Found pathway(s) for Thelymitra: ['C3']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Cremnophila is missing a pathway
# >>>Found pathway(s) for Cremnophila: ['CAM']
# Cremnophila is missing a pathway
# >>>Found pathway(s) for Cremnophila: ['CAM']
# Cremnophila is missing a pathway
# >>>Found pathway(s) for Cremnophila: ['CAM']
# Lenophyllum is missing a pathway
# >>>Found pathway(s) for Lenophyllum: ['CAM']
# Parvisedum is missing a pathway
# >>>Found pathway(s) for Parvisedum: ['CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Sedum is missing a pathway
# >>>Found pathway(s) for Sedum: ['C3-CAM']
# Cremnophila is missing a pathway
# >>>Found pathway(s) for Cremnophila: ['CAM']
# HYBRID is missing a pathway
# HYBRID is missing a pathway
# HYBRID is missing a pathway
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudia is missing a pathway
# >>>Found pathway(s) for Alluaudia: ['CAM']
# Alluaudiopsis is missing a pathway
# >>>Found pathway(s) for Alluaudiopsis: ['CAM']
# Decarya is missing a pathway
# >>>Found pathway(s) for Decarya: ['CAM']
# Decarya is missing a pathway
# >>>Found pathway(s) for Decarya: ['CAM']
# Decarya is missing a pathway
# >>>Found pathway(s) for Decarya: ['CAM']
# Didierea is missing a pathway
# >>>Found pathway(s) for Didierea: ['CAM']
# Didierea is missing a pathway
# >>>Found pathway(s) for Didierea: ['CAM']
# Didierea is missing a pathway
# >>>Found pathway(s) for Didierea: ['CAM']
# Didierea is missing a pathway
# >>>Found pathway(s) for Didierea: ['CAM']
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, [], -24.3
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, [], -25.6
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, [], -25.8
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, [], -24.6
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, [], -24.1
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, ['CAM', 'C4'], -17.8
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, ['CAM', 'C4'], -16.7
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, [], -22.7
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, [], -23.3
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, [], -23.6
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, [], -24.6
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, [], -24.3
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, [], -24.5
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, ['CAM', 'C4'], 13.2
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, ['CAM', 'C4'], -13.2
# Euphorbia is missing a pathway
# >>>Found pathway(s) for Euphorbia: ['CAM', 'C4']
# 	Some data: Euphorbia, ['CAM', 'C4'], 12.6
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -10.2
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -13.5
# Xerosicyos is missing a pathway
# >>>Found pathway(s) for Xerosicyos: ['CAM']
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -25.01
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -17.42
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.79
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.0
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -23.75
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -25.01
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -26.29
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -26.4
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -18.8
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -13.14
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.52
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -13.62
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -17.11
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.78
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -10.53
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -27.2
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -23.17
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -10.61
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], 13.69
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -11.99
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -11.35
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -15.09
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -25.48
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -22.95
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -13.86
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.71
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -23.69
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -11.21
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.92
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -14.15
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -16.15
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.77
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -14.21
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.16
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -11.74
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -27.34
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -18.75
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -13.85
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -13.16
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.69
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -15.19
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -19.86
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -17.9
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -23.22
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -16.07
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.96
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -30.06
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -28.12
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -15.68
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -22.46
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -27.0
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -25.62
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -15.21
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -23.91
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -13.16
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -17.1
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -16.18
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -16.91
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -19.25
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -13.24
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.87
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -16.33
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.81
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -11.15
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -14.09
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -11.44
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['C3-CAM'], -26.89
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.67
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.25
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -18.44
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -14.46
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -13.4
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -15.0
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -13.72
# Kalanchoe is missing a pathway
# >>>Found pathway(s) for Kalanchoe: ['CAM', 'C3-CAM']
# 	Some data: Kalanchoe, ['CAM', 'C3-CAM'], -12.25
# Yucca is missing a pathway
# >>>Found pathway(s) for Yucca: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Yucca, ['CAM', 'C3-CAM'], -14.07
# Yucca is missing a pathway
# >>>Found pathway(s) for Yucca: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Yucca, ['C3', 'C3-CAM'], -24.25
# Pitcairnia is missing a pathway
# >>>Found pathway(s) for Pitcairnia: ['C3']
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['C3'], -31.8
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['C3'], -30.7
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['C3'], -26.4
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['CAM'], -14.7
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['CAM'], -14.9
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['CAM'], -11.4
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['C3'], -28.6
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['C3'], -26.7
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['CAM'], -19.8
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['CAM'], -13.4
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['CAM'], -14.1
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['C3'], -32.4
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['CAM'], -11.2
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['CAM'], -19.2
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['CAM'], -18.5
# Tillandsia is missing a pathway
# >>>Found pathway(s) for Tillandsia: ['C3', 'CAM']
# 	Some data: Tillandsia, ['C3'], -29.4
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Vriesea is missing a pathway
# >>>Found pathway(s) for Vriesea: ['C3']
# Guzmania is missing a pathway
# >>>Found pathway(s) for Guzmania: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Guzmania, ['C3', 'C3-CAM'], -28.3
# Guzmania is missing a pathway
# >>>Found pathway(s) for Guzmania: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Guzmania, ['C3', 'C3-CAM'], -26.5
# Guzmania is missing a pathway
# >>>Found pathway(s) for Guzmania: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Guzmania, ['C3', 'C3-CAM'], -29.5
# Guzmania is missing a pathway
# >>>Found pathway(s) for Guzmania: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Guzmania, ['C3', 'C3-CAM'], -26.8
# Catopsis is missing a pathway
# >>>Found pathway(s) for Catopsis: ['C3']
# Catopsis is missing a pathway
# >>>Found pathway(s) for Catopsis: ['C3']
# Catopsis is missing a pathway
# >>>Found pathway(s) for Catopsis: ['C3']
# Glomeropitcairnia is missing a pathway
# Araeococcus is missing a pathway
# >>>Found pathway(s) for Araeococcus: ['CAM']
# Bromelia is missing a pathway
# >>>Found pathway(s) for Bromelia: ['CAM']
# Bromelia is missing a pathway
# >>>Found pathway(s) for Bromelia: ['CAM']
# Bromelia is missing a pathway
# >>>Found pathway(s) for Bromelia: ['CAM']
# Hohenbergia is missing a pathway
# >>>Found pathway(s) for Hohenbergia: ['CAM']
# Aechmea is missing a pathway
# >>>Found pathway(s) for Aechmea: ['CAM']
# Aechmea is missing a pathway
# >>>Found pathway(s) for Aechmea: ['CAM']
# Aechmea is missing a pathway
# >>>Found pathway(s) for Aechmea: ['CAM']
# Aechmea is missing a pathway
# >>>Found pathway(s) for Aechmea: ['CAM']
# Aechmea is missing a pathway
# >>>Found pathway(s) for Aechmea: ['CAM']
# Aechmea is missing a pathway
# >>>Found pathway(s) for Aechmea: ['CAM']
# Aechmea is missing a pathway
# >>>Found pathway(s) for Aechmea: ['CAM']
# Aechmea is missing a pathway
# >>>Found pathway(s) for Aechmea: ['CAM']
# Aechmea is missing a pathway
# >>>Found pathway(s) for Aechmea: ['CAM']
# Aechmea is missing a pathway
# >>>Found pathway(s) for Aechmea: ['CAM']
# Aechmea is missing a pathway
# >>>Found pathway(s) for Aechmea: ['CAM']
# Billbergia is missing a pathway
# >>>Found pathway(s) for Billbergia: ['C3', 'CAM']
# 	Some data: Billbergia, ['CAM'], -15.9
# Billbergia is missing a pathway
# >>>Found pathway(s) for Billbergia: ['C3', 'CAM']
# 	Some data: Billbergia, ['CAM'], -13.7
# Ananas is missing a pathway
# >>>Found pathway(s) for Ananas: ['CAM']
# Psilotum is missing a pathway
# Lycopodium is missing a pathway
# Lycopodium is missing a pathway
# Lycopodium is missing a pathway
# Asplenium is missing a pathway
# >>>Found pathway(s) for Asplenium: ['C3']
# Asplenium is missing a pathway
# >>>Found pathway(s) for Asplenium: ['C3']
# Asplenium is missing a pathway
# >>>Found pathway(s) for Asplenium: ['C3']
# Elaphoglossum is missing a pathway
# Ophioglossum is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# Belvisia is missing a pathway
# Belvisia is missing a pathway
# Drynaria is missing a pathway
# Dictymia is missing a pathway
# Microsorium is missing a pathway
# Platycerium is missing a pathway
# >>>Found pathway(s) for Platycerium: ['CAM']
# Platycerium is missing a pathway
# >>>Found pathway(s) for Platycerium: ['CAM']
# Platycerium is missing a pathway
# >>>Found pathway(s) for Platycerium: ['CAM']
# Platycerium is missing a pathway
# >>>Found pathway(s) for Platycerium: ['CAM']
# Platycerium is missing a pathway
# >>>Found pathway(s) for Platycerium: ['CAM']
# Platycerium is missing a pathway
# >>>Found pathway(s) for Platycerium: ['CAM']
# Platycerium is missing a pathway
# >>>Found pathway(s) for Platycerium: ['CAM']
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Pyrrosia, ['CAM', 'C3-CAM'], -19.2
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Pyrrosia, ['C3', 'C3-CAM'], -25.3
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Pyrrosia, ['CAM', 'C3-CAM'], -19.1
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Pyrrosia, ['CAM', 'C3-CAM'], -17.3
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Pyrrosia, ['CAM', 'C3-CAM'], -18.7
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Pyrrosia, ['CAM', 'C3-CAM'], -14.2
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Pyrrosia, ['CAM', 'C3-CAM'], -13.6
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Pyrrosia, ['C3', 'C3-CAM'], -29.1
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# 	Some data: Pyrrosia, ['C3', 'C3-CAM'], -23.9
# Antrophyum is missing a pathway
# Vittaria is missing a pathway
# >>>Found pathway(s) for Vittaria: ['CAM']
# Bowenia is missing a pathway
# Parsonsia is missing a pathway
# Schefflera is missing a pathway
# Dischidia is missing a pathway
# >>>Found pathway(s) for Dischidia: ['CAM']
# Dischidia is missing a pathway
# >>>Found pathway(s) for Dischidia: ['CAM']
# Dischidia is missing a pathway
# >>>Found pathway(s) for Dischidia: ['CAM']
# Dischidia is missing a pathway
# >>>Found pathway(s) for Dischidia: ['CAM']
# Dischidia is missing a pathway
# >>>Found pathway(s) for Dischidia: ['CAM']
# Hoya is missing a pathway
# >>>Found pathway(s) for Hoya: ['CAM']
# Hoya is missing a pathway
# >>>Found pathway(s) for Hoya: ['CAM']
# Hoya is missing a pathway
# >>>Found pathway(s) for Hoya: ['CAM']
# Hoya is missing a pathway
# >>>Found pathway(s) for Hoya: ['CAM']
# Hoya is missing a pathway
# >>>Found pathway(s) for Hoya: ['CAM']
# Hoya is missing a pathway
# >>>Found pathway(s) for Hoya: ['CAM']
# Itoya is missing a pathway
# Itoya is missing a pathway
# Marsdenia is missing a pathway
# Dimorphanthera is missing a pathway
# Boea is missing a pathway
# Boea is missing a pathway
# Plectranthus is missing a pathway
# >>>Found pathway(s) for Plectranthus: ['CAM']
# Plectranthus is missing a pathway
# >>>Found pathway(s) for Plectranthus: ['CAM']
# Amyema is missing a pathway
# Amyema is missing a pathway
# Notothixus is missing a pathway
# Ficus is missing a pathway
# Peperomia is missing a pathway
# >>>Found pathway(s) for Peperomia: ['C3-CAM']
# Peperomia is missing a pathway
# >>>Found pathway(s) for Peperomia: ['C3-CAM']
# Peperomia is missing a pathway
# >>>Found pathway(s) for Peperomia: ['C3-CAM']
# Peperomia is missing a pathway
# >>>Found pathway(s) for Peperomia: ['C3-CAM']
# Peperomia is missing a pathway
# >>>Found pathway(s) for Peperomia: ['C3-CAM']
# Peperomia is missing a pathway
# >>>Found pathway(s) for Peperomia: ['C3-CAM']
# Peperomia is missing a pathway
# >>>Found pathway(s) for Peperomia: ['C3-CAM']
# Fragraea is missing a pathway
# Hydnophytum is missing a pathway
# >>>Found pathway(s) for Hydnophytum: ['CAM']
# Hydnophytum is missing a pathway
# >>>Found pathway(s) for Hydnophytum: ['CAM']
# Myrmecodia is missing a pathway
# >>>Found pathway(s) for Myrmecodia: ['CAM']
# Myrmecodia is missing a pathway
# >>>Found pathway(s) for Myrmecodia: ['CAM']
# Myrmecodia is missing a pathway
# >>>Found pathway(s) for Myrmecodia: ['CAM']
# Myrmecodia is missing a pathway
# >>>Found pathway(s) for Myrmecodia: ['CAM']
# Myrmecodia is missing a pathway
# >>>Found pathway(s) for Myrmecodia: ['CAM']
# Timonius is missing a pathway
# Timonius is missing a pathway
# Elatostemma is missing a pathway
# Procris is missing a pathway
# Agapetes is missing a pathway
# Pothos is missing a pathway
# Rhaphidophora is missing a pathway
# Pollia is missing a pathway
# Geitonoplesium is missing a pathway
# Geitonoplesium is missing a pathway
# Acianthus is missing a pathway
# >>>Found pathway(s) for Acianthus: ['C3']
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['CAM'], -12.4
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['CAM'], -16.8
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['CAM'], -14.9
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['CAM'], -13.9
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['CAM'], -12.1
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -25.1
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -22.1
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -27.4
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -26.2
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -22.6
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -27.9
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -25.3
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['CAM'], -12.2
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['CAM'], -12.0
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['CAM'], -17.0
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -24.0
# Cadetia is missing a pathway
# >>>Found pathway(s) for Cadetia: ['CAM']
# Cadetia is missing a pathway
# >>>Found pathway(s) for Cadetia: ['CAM']
# Cadetia is missing a pathway
# >>>Found pathway(s) for Cadetia: ['CAM']
# Cadetia is missing a pathway
# >>>Found pathway(s) for Cadetia: ['CAM']
# Calanthe is missing a pathway
# >>>Found pathway(s) for Calanthe: ['CAM']
# Chiloschista is missing a pathway
# >>>Found pathway(s) for Chiloschista: ['CAM']
# Chiloschista is missing a pathway
# >>>Found pathway(s) for Chiloschista: ['CAM']
# Cymbidium is missing a pathway
# >>>Found pathway(s) for Cymbidium: ['C3', 'CAM']
# 	Some data: Cymbidium, ['CAM'], -18.7
# Cymbidium is missing a pathway
# >>>Found pathway(s) for Cymbidium: ['C3', 'CAM']
# 	Some data: Cymbidium, ['CAM'], -16.8
# Cymbidium is missing a pathway
# >>>Found pathway(s) for Cymbidium: ['C3', 'CAM']
# 	Some data: Cymbidium, ['C3'], -27.0
# Cymbidium is missing a pathway
# >>>Found pathway(s) for Cymbidium: ['C3', 'CAM']
# 	Some data: Cymbidium, ['C3'], -27.0
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -26.3
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -23.6
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -27.7
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -24.9
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -14.1
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -26.7
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -27.6
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -32.0
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -32.5
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -14.7
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -18.1
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -11.9
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -13.1
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -10.5
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -28.8
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -13.5
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -14.1
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -13.8
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -25.0
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -18.3
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -25.2
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -13.9
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -13.4
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -14.4
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -12.6
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -11.9
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -14.5
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -18.7
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -25.8
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -25.2
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -13.5
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -25.1
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -15.4
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -13.9
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -14.5
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -15.0
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -26.8
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -24.2
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -28.5
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -27.9
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -14.5
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -14.8
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -15.3
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -15.9
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -25.9
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -15.9
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -15.8
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -18.2
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -15.7
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -17.6
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['C3'], -25.4
# Dendrobium is missing a pathway
# >>>Found pathway(s) for Dendrobium: ['C3', 'CAM']
# 	Some data: Dendrobium, ['CAM'], -13.1
# Diplocaulobium is missing a pathway
# Dipodium is missing a pathway
# Dipodium is missing a pathway
# Eria is missing a pathway
# >>>Found pathway(s) for Eria: ['C3', 'CAM']
# 	Some data: Eria, ['C3'], -28.9
# Eria is missing a pathway
# >>>Found pathway(s) for Eria: ['C3', 'CAM']
# 	Some data: Eria, ['C3'], -28.7
# Eria is missing a pathway
# >>>Found pathway(s) for Eria: ['C3', 'CAM']
# 	Some data: Eria, ['C3'], -28.3
# Eria is missing a pathway
# >>>Found pathway(s) for Eria: ['C3', 'CAM']
# 	Some data: Eria, ['C3'], -28.4
# Eria is missing a pathway
# >>>Found pathway(s) for Eria: ['C3', 'CAM']
# 	Some data: Eria, ['CAM'], -19.8
# Flickingeria is missing a pathway
# >>>Found pathway(s) for Flickingeria: ['CAM']
# Flickingeria is missing a pathway
# >>>Found pathway(s) for Flickingeria: ['CAM']
# Goodyera is missing a pathway
# >>>Found pathway(s) for Goodyera: ['C3']
# Liparis is missing a pathway
# Liparis is missing a pathway
# Liparis is missing a pathway
# Liparis is missing a pathway
# Liparis is missing a pathway
# Liparis is missing a pathway
# Liparis is missing a pathway
# Liparis is missing a pathway
# Luisia is missing a pathway
# >>>Found pathway(s) for Luisia: ['CAM']
# Micropera is missing a pathway
# >>>Found pathway(s) for Micropera: ['CAM']
# Micropera is missing a pathway
# >>>Found pathway(s) for Micropera: ['CAM']
# Mobilabium is missing a pathway
# >>>Found pathway(s) for Mobilabium: ['CAM']
# Oberonia is missing a pathway
# >>>Found pathway(s) for Oberonia: ['CAM']
# Oberonia is missing a pathway
# >>>Found pathway(s) for Oberonia: ['CAM']
# Phalaenopsis is missing a pathway
# >>>Found pathway(s) for Phalaenopsis: ['CAM']
# Pholidota is missing a pathway
# ...
# Rodriguezia is missing a pathway
# >>>Found pathway(s) for Rodriguezia: ['CAM']
# Rodriguezia is missing a pathway
# >>>Found pathway(s) for Rodriguezia: ['CAM']
# Rossioglossum is missing a pathway
# >>>Found pathway(s) for Rossioglossum: ['CAM']
# Rossioglossum is missing a pathway
# >>>Found pathway(s) for Rossioglossum: ['CAM']
# Rossioglossum is missing a pathway
# >>>Found pathway(s) for Rossioglossum: ['CAM']
# Rossioglossum is missing a pathway
# >>>Found pathway(s) for Rossioglossum: ['CAM']
# Systeloglossum is missing a pathway
# Systeloglossum is missing a pathway
# Systeloglossum is missing a pathway
# Telipogon is missing a pathway
# Telipogon is missing a pathway
# Telipogon is missing a pathway
# Telipogon is missing a pathway
# Trichocentrum is missing a pathway
# >>>Found pathway(s) for Trichocentrum: ['CAM']
# Trichocentrum is missing a pathway
# >>>Found pathway(s) for Trichocentrum: ['CAM']
# Trichocentrum is missing a pathway
# >>>Found pathway(s) for Trichocentrum: ['CAM']
# Trichocentrum is missing a pathway
# >>>Found pathway(s) for Trichocentrum: ['CAM']
# Trichocentrum is missing a pathway
# >>>Found pathway(s) for Trichocentrum: ['CAM']
# Trichocentrum is missing a pathway
# >>>Found pathway(s) for Trichocentrum: ['CAM']
# Trichocentrum is missing a pathway
# >>>Found pathway(s) for Trichocentrum: ['CAM']
# Trichocentrum is missing a pathway
# >>>Found pathway(s) for Trichocentrum: ['CAM']
# Trichocentrum is missing a pathway
# >>>Found pathway(s) for Trichocentrum: ['CAM']
# Trichopilia is missing a pathway
# >>>Found pathway(s) for Trichopilia: ['CAM']
# Trichopilia is missing a pathway
# >>>Found pathway(s) for Trichopilia: ['CAM']
# Trichopilia is missing a pathway
# >>>Found pathway(s) for Trichopilia: ['CAM']
# Trichopilia is missing a pathway
# >>>Found pathway(s) for Trichopilia: ['CAM']
# Trizeuxis is missing a pathway
# >>>Found pathway(s) for Trizeuxis: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Camaridium is missing a pathway
# >>>Found pathway(s) for Camaridium: ['CAM']
# Christensonella is missing a pathway
# Cryptocentrum is missing a pathway
# Cryptocentrum is missing a pathway
# Cryptocentrum is missing a pathway
# Cryptocentrum is missing a pathway
# Cryptocentrum is missing a pathway
# Cryptocentrum is missing a pathway
# Cryptocentrum is missing a pathway
# Heterotaxis is missing a pathway
# >>>Found pathway(s) for Heterotaxis: ['CAM']
# Heterotaxis is missing a pathway
# >>>Found pathway(s) for Heterotaxis: ['CAM']
# Heterotaxis is missing a pathway
# >>>Found pathway(s) for Heterotaxis: ['CAM']
# Heterotaxis is missing a pathway
# >>>Found pathway(s) for Heterotaxis: ['CAM']
# Inti is missing a pathway
# Inti is missing a pathway
# Lycaste is missing a pathway
# Lycaste is missing a pathway
# Lycaste is missing a pathway
# Lycaste is missing a pathway
# Lycaste is missing a pathway
# Lycaste is missing a pathway
# Mapinguari is missing a pathway
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillaria is missing a pathway
# >>>Found pathway(s) for Maxillaria: ['CAM']
# Maxillariella is missing a pathway
# Maxillariella is missing a pathway
# Maxillariella is missing a pathway
# Maxillariella is missing a pathway
# Maxillariella is missing a pathway
# Maxillariella is missing a pathway
# Maxillariella is missing a pathway
# Maxillariella is missing a pathway
# Maxillariella is missing a pathway
# Maxillariella is missing a pathway
# Maxillariella is missing a pathway
# Maxillariella is missing a pathway
# Mormolyca is missing a pathway
# Mormolyca is missing a pathway
# Mormolyca is missing a pathway
# Mormolyca is missing a pathway
# Mormolyca is missing a pathway
# Mormolyca is missing a pathway
# Nitidobulbon is missing a pathway
# Ornithidium is missing a pathway
# >>>Found pathway(s) for Ornithidium: ['CAM']
# Ornithidium is missing a pathway
# >>>Found pathway(s) for Ornithidium: ['CAM']
# Ornithidium is missing a pathway
# >>>Found pathway(s) for Ornithidium: ['CAM']
# Ornithidium is missing a pathway
# >>>Found pathway(s) for Ornithidium: ['CAM']
# Ornithidium is missing a pathway
# >>>Found pathway(s) for Ornithidium: ['CAM']
# Ornithidium is missing a pathway
# >>>Found pathway(s) for Ornithidium: ['CAM']
# Rhetinantha is missing a pathway
# Rhetinantha is missing a pathway
# Rhetinantha is missing a pathway
# Rhetinantha is missing a pathway
# Trigonidium is missing a pathway
# >>>Found pathway(s) for Trigonidium: ['CAM']
# Trigonidium is missing a pathway
# >>>Found pathway(s) for Trigonidium: ['CAM']
# Trigonidium is missing a pathway
# >>>Found pathway(s) for Trigonidium: ['CAM']
# Trigonidium is missing a pathway
# >>>Found pathway(s) for Trigonidium: ['CAM']
# Xylobium is missing a pathway
# Xylobium is missing a pathway
# Xylobium is missing a pathway
# Xylobium is missing a pathway
# Coryanthes is missing a pathway
# >>>Found pathway(s) for Coryanthes: ['CAM']
# Gongora is missing a pathway
# Gongora is missing a pathway
# Gongora is missing a pathway
# Gongora is missing a pathway
# Gongora is missing a pathway
# Houlletia is missing a pathway
# Houlletia is missing a pathway
# Kegeliella is missing a pathway
# Polycycnis is missing a pathway
# Polycycnis is missing a pathway
# Polycycnis is missing a pathway
# Stanhopea is missing a pathway
# Stanhopea is missing a pathway
# Stanhopea is missing a pathway
# Stanhopea is missing a pathway
# Stanhopea is missing a pathway
# Stanhopea is missing a pathway
# Stanhopea is missing a pathway
# Coeliopsis is missing a pathway
# Peristeria is missing a pathway
# >>>Found pathway(s) for Peristeria: ['CAM']
# Chondrorhyncha is missing a pathway
# Chondrorhyncha is missing a pathway
# Chondrorhyncha is missing a pathway
# Chondroscaphe is missing a pathway
# Cochleanthes is missing a pathway
# Cryptarrhena is missing a pathway
# Cryptarrhena is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Dichaea is missing a pathway
# Euryblema is missing a pathway
# Galeottia is missing a pathway
# Huntleya is missing a pathway
# Huntleya is missing a pathway
# Huntleya is missing a pathway
# Kefersteinia is missing a pathway
# Kefersteinia is missing a pathway
# Kefersteinia is missing a pathway
# Kefersteinia is missing a pathway
# Koellensteinia is missing a pathway
# Pescatoria is missing a pathway
# Pescatoria is missing a pathway
# Stenotyla is missing a pathway
# Warczewiczella is missing a pathway
# Warczewiczella is missing a pathway
# Warrea is missing a pathway
# Subtribe is missing a pathway
# Polystachya is missing a pathway
# Campylocentrum is missing a pathway
# >>>Found pathway(s) for Campylocentrum: ['CAM']
# Campylocentrum is missing a pathway
# >>>Found pathway(s) for Campylocentrum: ['CAM']
# Campylocentrum is missing a pathway
# >>>Found pathway(s) for Campylocentrum: ['CAM']
# Campylocentrum is missing a pathway
# >>>Found pathway(s) for Campylocentrum: ['CAM']
# Bulbophyllum is missing a pathway
# >>>Found pathway(s) for Bulbophyllum: ['C3', 'CAM']
# 	Some data: Bulbophyllum, ['C3'], -28.1
# Calanthe is missing a pathway
# >>>Found pathway(s) for Calanthe: ['CAM']
# Calanthe is missing a pathway
# >>>Found pathway(s) for Calanthe: ['CAM']
# Spathoglottis is missing a pathway
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# Pyrrosia is missing a pathway
# >>>Found pathway(s) for Pyrrosia: ['C3', 'CAM', 'C3-CAM']
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway
# nan is missing a pathway

# %%
mylist = ['C3', 'CAM']
print mylist
mylist = list(set(mylist)-set(['CAM']))
mylist list(set(mylist)-set(['CAM']))
print mylist
# mylist.remove('foo')
# Out:
# ['C3', 'CAM']
# ['C3']

# %%
list(set(mylist)-set(['CAM']))
# Out:
# ['C3']

# %%
fill_dict={}
# Loop over categories
for cat in to_fill:
    filled_holes=0
    # Create temporary dataframe with category modes
    modeframe = catmode(df, key_col=group_by, value_col=cat)
    for index, row in copy.iterrows():
        taxon = copy.loc[index, group_by]
        # Skip unidentified taxa
        if taxon.lower() in ['species', 'sp', 'spp', 'spec', 'sp.', 'spp.', 'spec.']:
            if debug: print("UH OH. UNIDENTIFIED TAXON: {}".format(taxon))
            continue
        # Only fill if current value is missing
        current = copy.loc[index, cat]
        if debug: print("Current taxon: {}, pathway: {}".format(taxon, current))
        if check_nan(current) and taxon in modeframe[group_by].tolist():
            if debug: print("\tFOUND A HOLE IN {}".format(taxon))
            rankmode = modeframe.loc[modeframe[group_by]==taxon][cat].tolist()[0]
            if debug: print("\tFound a mode for {}: {}".format(taxon, rankmode))
        else:
            rankmode = np.NaN
            if debug: print("\t\tCANT FILL HOLE for {}: {}".format(taxon, rankmode))
        copy.loc[index, cat] = rankmode
if debug: print fill_dict

# %%
fam_pct_id = {}
for family, row in thelist.iterrows():
    if type(thelist.loc[family].count())!=np.int64:
        fam_pct_id[family] = sorted(thelist.loc[family].count())[1]/float(thelist.loc[family].count()['Genus'])
    else:
        fam_pct_id[family] = 0.0

# %%
fam_pct = pd.DataFrame(columns=['Family', 'pct'])
fam_pct['Family'] = sorted(fam_pct_id.keys())
fam_pct['pct'] = [fam_pct_id[fam] for fam in sorted(fam_pct_id.keys())]
fam_pct['size'] = [len(thelist.loc[fam]) for fam in fam_pct['Family']]

# %%
fam_pct.head()
# Out:
#             Family       pct  size
# 0      Acanthaceae  0.007092   423
# 1      Achariaceae  0.000000    37
# 2  Achatocarpaceae  0.000000     2
# 3        Acoraceae  0.000000     7
# 4    Actinidiaceae  0.000000     4

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(14,7))

ax0.hist(x=fam_pct['pct'], edgecolor='grey',linewidth=2, color='grey', alpha=0.5, bins=20)

ax1.scatter(x=fam_pct['size'], y=fam_pct['pct'], color="grey", alpha=0.3)
ax1.scatter(x=fam_pct.loc[fam_pct["Family"]=="Orchidaceae", "size"], 
            y=fam_pct.loc[fam_pct["Family"]=="Orchidaceae","pct"],
            color="magenta", s=75)
ax1.scatter(x=fam_pct.loc[fam_pct["Family"]=="Bromeliaceae", "size"], 
            y=fam_pct.loc[fam_pct["Family"]=="Bromeliaceae","pct"],
            color="blue", s=75)
ax1.scatter(x=fam_pct.loc[fam_pct["Family"]=="Poaceae", "size"], 
            y=fam_pct.loc[fam_pct["Family"]=="Poaceae","pct"],
            color="green", s=75)
ax1.scatter(x=fam_pct.loc[fam_pct["Family"]=="Cactaceae", "size"], 
            y=fam_pct.loc[fam_pct["Family"]=="Cactaceae","pct"],
            color="orange", s=75)
ax1.scatter(x=fam_pct.loc[fam_pct["Family"]=="Isoetaceae", "size"], 
            y=fam_pct.loc[fam_pct["Family"]=="Isoetaceae","pct"],
            color="brown", s=75)

ax1.text(x=fam_pct.loc[fam_pct["Family"]=="Bromeliaceae", "size"]-10, 
            y=fam_pct.loc[fam_pct["Family"]=="Bromeliaceae","pct"]+0.03, 
            s="Bromeliaceae", size=16)
ax1.text(x=fam_pct.loc[fam_pct["Family"]=="Orchidaceae", "size"]-750, 
            y=fam_pct.loc[fam_pct["Family"]=="Orchidaceae","pct"]+0.03, 
            s="Orchidaceae", size=16)
ax1.text(x=fam_pct.loc[fam_pct["Family"]=="Poaceae", "size"]-100, 
            y=fam_pct.loc[fam_pct["Family"]=="Poaceae","pct"]+0.03, 
            s="Poaceae", size=16)
ax1.text(x=fam_pct.loc[fam_pct["Family"]=="Cactaceae", "size"]-10, 
            y=fam_pct.loc[fam_pct["Family"]=="Cactaceae","pct"]+0.03, 
            s="Cactaceae", size=16)
ax1.text(x=fam_pct.loc[fam_pct["Family"]=="Isoetaceae", "size"], 
            y=fam_pct.loc[fam_pct["Family"]=="Isoetaceae","pct"]+0.03, 
            s="Isoetaceae", size=16)

ax0.set_yscale('log')
ax1.set_xscale('log')
ax1.set_ylim([-0.05, 1.1])

ax0.set_xlabel("Fraction genera characterized per family", size=16)
ax0.set_ylabel("$log$(Number of families)", size=16)
ax1.set_xlabel("$log$(Genera per family)", size=16)
ax1.set_ylabel("Fraction genera characterized per family", size=16)
plt.savefig('/Users/iangilman/GitHub/photo_db/images/thelist_pct_char.pdf', format='pdf', transparent=True, dpi=300);

# %% [markdown]
# # Males (2018): Bromeliads
# The first part of this example will use data from Males (2018), which consists of
# * Air channel area ($\mu$m$^2$),
# * Chlorenchyma diameter ($\mu$m),
# * Chlorenchyma to hydrenchyma ratio,
# * Chlorenchyma vertical thickness ($\mu$m),
# * Hydrenchyma vertical thickness ($\mu$m)', and
# * Leaf thickness ($\mu$m).
# The data originally included intercellular airspace, but I'll drop this (see below).

# %%
broms_2018 = cam_db[cam_db['Source']=='Males (2018)']
broms_2018.reset_index(drop=True, inplace=True)
# Retain only those features with measurements
broms_2018 = broms_2018[['long_name', 'air_channel_area_um2', 'chlorenchyma_diameter_um', 
                       'chlorenchyma_hydrenchyma_ratio', 'chlorenchyma_vertical_thickness_um', 
                       'hydrenchyma_vertical_thickness_um', 'leaf_thickness_um', 
                    'Family', 'Subfamily', 'Pathway', 'IAS']]
broms_2018.head()
# Out:
#                                  long_name  air_channel_area_um2  \
# 0               Acanthostachys strobilacea               14082.0
# 1                             Aechmea alba               13110.0
# 2  Aechmea bromeliifolia var albobracteata               92331.0
# 3  Aechmea bromeliifolia var bromeliifolia               68975.0
# 4                        Aechmea capixabae                7243.0
#
#    chlorenchyma_diameter_um  chlorenchyma_hydrenchyma_ratio  \
# 0                     28.77                            0.37
# 1                     34.69                           11.38
# 2                     47.89                            2.96
# 3                     50.20                            8.86
# 4                     37.79                            0.69
#
#    chlorenchyma_vertical_thickness_um  hydrenchyma_vertical_thickness_um  \
# 0                              830.72                            2248.75
# 1                              747.03                              65.62
# 2                             1772.49                             597.95
# 3                             1291.67                             145.75
# 4                              353.61                             514.35
#
#    leaf_thickness_um        Family      Subfamily Pathway  IAS
# 0            3079.47  Bromeliaceae  Bromelioideae     CAM  NaN
# 1             812.65  Bromeliaceae  Bromelioideae     CAM  NaN
# 2            2370.44  Bromeliaceae  Bromelioideae     CAM  NaN
# 3            1437.42  Bromeliaceae  Bromelioideae     CAM  NaN
# 4             867.96  Bromeliaceae  Bromelioideae     CAM  NaN

# %%
db_info(cam_db=broms_2018, plt_missingdata=True, figsize=(6,3), labels=True, fontsize=12)
# Out:
# The CAM database consists of:
# 	163 observations,
# 	1 families,
# 	3 subfamiles,
# 	None tribes,
# 	None subtribes,
# 	None genera, and
# 	163 species from None publications.
# 0.0959 of the data matrix is missing and
# 162 observations have known photosynthetic pathways.

# %%
# Show some basic statistics
broms_2018.describe()
# Out:
#        air_channel_area_um2  chlorenchyma_diameter_um  \
# count            127.000000                163.000000
# mean           31669.456693                 31.923926
# std            41415.959926                 21.640931
# min              404.000000                  9.250000
# 25%            10490.000000                 15.045000
# 50%            15257.000000                 25.090000
# 75%            40266.000000                 42.050000
# max           351516.000000                124.160000
#
#        chlorenchyma_hydrenchyma_ratio  chlorenchyma_vertical_thickness_um  \
# count                      156.000000                          163.000000
# mean                         1.935000                          556.992147
# std                          3.197948                          476.897201
# min                          0.130000                           70.650000
# 25%                          0.557500                          202.500000
# 50%                          0.900000                          390.070000
# 75%                          1.542500                          735.980000
# max                         24.000000                         2518.360000
#
#        hydrenchyma_vertical_thickness_um  leaf_thickness_um        IAS
# count                         156.000000         163.000000  42.000000
# mean                          487.255321        1023.322270   9.145000
# std                           433.609592         710.544097   4.401081
# min                            31.780000         170.730000   4.160000
# 25%                           216.595000         497.725000   5.857500
# 50%                           336.500000         770.460000   7.095000
# 75%                           582.242500        1437.820000  12.412500
# max                          2962.680000        4085.720000  19.420000

# %%
print("There are {} IAS measurements. This is {:2.1f}% of all species".format(
    len(broms_2018['IAS'].unique()), 100*float(len(broms_2018['IAS'].unique()))/len(broms_2018)))
# Out:
# There are 42 IAS measurements. This is 25.8% of all species

# %% [markdown]
# For this reason, I'll drop this feature from the dataset, along with other taxa with missing data. This leaves us with 122 observations.

# %%
broms_2018.drop(labels=['IAS'], axis=1, inplace=True)
broms_2018.dropna(inplace=True)
broms_2018.reset_index(drop=True, inplace=True)

# %%
db_info(cam_db=broms_2018, plt_missingdata=True, figsize=(6,3), labels=True, fontsize=12)
# Out:
# The CAM database consists of:
# 	123 observations,
# 	1 families,
# 	3 subfamiles,
# 	None tribes,
# 	None subtribes,
# 	None genera, and
# 	123 species from None publications.
# 0.0 of the data matrix is missing and
# 123 observations have known photosynthetic pathways.

# %%
brom_features = ['air_channel_area_um2', 'chlorenchyma_diameter_um',
                'chlorenchyma_hydrenchyma_ratio', 'chlorenchyma_vertical_thickness_um',
                'hydrenchyma_vertical_thickness_um', 'leaf_thickness_um']

# %% [markdown]
# ### Visualization of raw and log-transformed data
# Now that we've gotten a complete matrix, let's see what the data look like. I'll run analyses of the raw data as well as log-transformed data, as in Males (2018).

# %%
g = sns.pairplot(broms_2018, hue="Pathway", markers='o', size=1)
g.fig.set_size_inches(12, 12)
replacements = dict(zip(brom_features,['Air channel\narea ($\mu$m$^2$)',
                                       'Chlorenchyma\ndiameter ($\mu$m)',
                                       'Chlor:hydr ratio',
                                       'Chlorenchyma vertical\nthickness ($\mu$m)',
                                       'Hydrenchyma vertical\nthickness ($\mu$m)',
                                       'Leaf thickness ($\mu$m)']))

for i in range(len(brom_features)):
    for j in range(len(brom_features)):
        xlabel = g.axes[i][j].get_xlabel()
        ylabel = g.axes[i][j].get_ylabel()
        if xlabel in replacements.keys():
            g.axes[i][j].set_xlabel(replacements[xlabel], size=12)
        if ylabel in replacements.keys():
            g.axes[i][j].set_ylabel(replacements[ylabel], size=12)

g.fig.get_children()[-1].set_bbox_to_anchor((0.25, 0.975, 0, 0))

plt.tight_layout();

# %% [markdown]
# Create log-transformed dataframe

# %%
logbroms_2018 = np.log(broms_2018[brom_features]).join(broms_2018[list(set(broms_2018.columns)-set(brom_features))])

# %%
g = sns.pairplot(logbroms_2018, hue="Pathway", markers='o', size=1,)
g.fig.set_size_inches(12, 12)
replacements = dict(zip(brom_features,['Air channel\narea ($\mu$m$^2$)',
                                       'Chlorenchyma\ndiameter ($\mu$m)',
                                       'Chlor:hydr ratio',
                                       'Chlorenchyma vertical\nthickness ($\mu$m)',
                                       'Hydrenchyma vertical\nthickness ($\mu$m)',
                                       'Leaf thickness ($\mu$m)']))

for i in range(len(brom_features)):
    for j in range(len(brom_features)):
        xlabel = g.axes[i][j].get_xlabel()
        ylabel = g.axes[i][j].get_ylabel()
        if xlabel in replacements.keys():
            g.axes[i][j].set_xlabel(replacements[xlabel], size=12)
        if ylabel in replacements.keys():
            g.axes[i][j].set_ylabel(replacements[ylabel], size=12)

g.fig.get_children()[-1].set_bbox_to_anchor((0.24, 0.9999, 0, 0))
plt.tight_layout();
# plt.savefig("/Users/iangilman/Downloads/brom_log_scatter.pdf", tranparent=True, dpi=300, bbox_inches="tight");

# %% [markdown]
# Plot scatter matrix for log-tranformed data.
#
# Take a look at the correlation between measurements. Heatmaps are okay for qualitative assessments but I don't like them for quantitative judgements.

# %%
# Compute the correlation matrix
brom_2018_corr = broms_2018[brom_features].corr()

# Generate a mask for the upper triangle
brom_2018_mask = np.zeros_like(brom_2018_corr, dtype=np.bool)
brom_2018_mask[np.triu_indices_from(brom_2018_mask)] = True

# Repeat for log-transformed
logbrom_2018_corr = logbroms_2018[brom_features].corr()
logbrom_2018_mask = np.zeros_like(logbrom_2018_corr, dtype=np.bool)
logbrom_2018_mask[np.triu_indices_from(logbrom_2018_mask)] = True

# %%
fig, (ax0, ax1) = plt.subplots(1,2, figsize=(12, 6))

sns.heatmap(brom_2018_corr, annot=True, mask=brom_2018_mask, cmap="RdBu_r", center=0,
            square=True, linewidths=.5, cbar=False, ax=ax0)
sns.heatmap(logbrom_2018_corr, annot=True, mask=logbrom_2018_mask, cmap="RdBu_r", center=0,
            square=True, linewidths=.5, cbar=True, ax=ax1)

ax0.set_title('Non-transformed')
ax0.set_xticks([0.5, 1.5, 2.5, 3.5, 4.5])
ax0.set_yticks([1.5, 2.5, 3.5, 4.5, 5.5])
ax1.set_title('Log-transformed')
ax1.set_xticks([0.5, 1.5, 2.5, 3.5, 4.5])
ax1.set_yticks([1.5, 2.5, 3.5, 4.5, 5.5])

plt.tight_layout();

# %%
fig, (ax0, ax1) = plt.subplots(1,2, figsize=(8, 4))

# Get regression stats
regstats = sp.stats.linregress(x=broms_2018['chlorenchyma_vertical_thickness_um'],
                               y=broms_2018['chlorenchyma_diameter_um'])
logregstats= sp.stats.linregress(x=logbroms_2018['chlorenchyma_vertical_thickness_um'], 
                                 y=logbroms_2018['chlorenchyma_diameter_um'])
sns.regplot('chlorenchyma_vertical_thickness_um', 'chlorenchyma_diameter_um', data=broms_2018, ax=ax0)
sns.regplot('chlorenchyma_vertical_thickness_um', 'chlorenchyma_diameter_um', data=logbroms_2018, ax=ax1)

ax1.set_xlim([min(logbroms_2018['chlorenchyma_vertical_thickness_um']-0.5),
              max(logbroms_2018['chlorenchyma_vertical_thickness_um']+0.5)])
ax1.set_ylim([min(logbroms_2018['chlorenchyma_diameter_um']-0.5),
              max(logbroms_2018['chlorenchyma_diameter_um']+0.5)])

ax0.text(300, 100, "$r^2$="+str(round(regstats[2]**2,3))+"\n$p$="+str('{:0.3e}'.format(
    regstats[3])), size=16)
ax1.text(4.5, 4.5, "$r^2$="+str(round(logregstats[2]**2,3))+"\n$p$="+str('{:0.3e}'.format(
    logregstats[3])), size=16)

ax0.set_xlabel("Chlorenchyma vertical thickness ($\mu$m)")
ax0.set_ylabel("Chlorenchyma diameter ($\mu$m)")
ax1.set_xlabel("Chlorenchyma vertical thickness ($\mu$m)")
ax1.set_ylabel("Chlorenchyma diameter ($\mu$m)")

ax0.set_title("Non-transformed")
ax1.set_title("Log-transformed")

plt.tight_layout();

# %% [markdown]
# The plot above is a replicate of Males Fig. 4a. He reports an $r^2=0.37$, while ours is $0.38$, so we aren't far off after removing some of the data. We should expect these measurements to be correlated as they are both distance measurements from the same cells.
#
# Next, we'll replicate the PCA.
# ### PCA

# %%
brom_pca_config = PCA(n_components=2)
brom_temp = broms_2018[brom_features]
brom_PCA = brom_pca_config.fit(brom_temp).transform(brom_temp)

logbrom_pca_config = PCA(n_components=2)
logbrom_temp = logbroms_2018[brom_features]
logbrom_PCA = logbrom_pca_config.fit(logbrom_temp).transform(logbrom_temp)

print('Explained variance ratio (first two components): {}'.format(brom_pca_config.explained_variance_ratio_))
print('Log-transformed explained variance ratio (first two components): {}'.format(
    logbrom_pca_config.explained_variance_ratio_))
# Out:
# Explained variance ratio (first two components): [  9.99704620e-01   2.52636712e-04]
# Log-transformed explained variance ratio (first two components): [ 0.54351906  0.27629338]

# %% [markdown]
# The untransformed data explains over 99% of the total variance while the log-transformed data explains about 82% (consistent with Male's analysis).

# %%
# Plotting shortcuts
color_map = {'C3':'green', 'CAM':'blue', 'C3-CAM':'red'}
shape_map = {'Bromelioideae':'o', 'Tillandsioideae':'^', 'Pitcairnioideae':'*'}

# %%
brom_PCA_DF = pd.DataFrame(brom_PCA, columns=['X', 'Y'])
brom_PCA_DF['Pathway'] = broms_2018['Pathway']
brom_PCA_DF['Subfamily'] = broms_2018['Subfamily']
brom_PCA_DF['color'] = [color_map[pathway] for pathway in brom_PCA_DF['Pathway']]
brom_PCA_DF['shape'] = [shape_map[subfam] for subfam in brom_PCA_DF['Subfamily']]

logbrom_PCA_DF = pd.DataFrame(logbrom_PCA, columns=['X', 'Y'])
logbrom_PCA_DF['Pathway'] = logbroms_2018['Pathway']
logbrom_PCA_DF['Subfamily'] = logbroms_2018['Subfamily']
logbrom_PCA_DF['color'] = [color_map[pathway] for pathway in logbrom_PCA_DF['Pathway']]
logbrom_PCA_DF['shape'] = [shape_map[subfam] for subfam in logbrom_PCA_DF['Subfamily']]

# %%
#fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(12, 6))
fig, ax1 = plt.subplots(figsize=(6,6))

# for i in range(len(brom_PCA_DF)):
#     if brom_PCA_DF['Pathway'][i]=='CAM':
#         ax0.scatter(brom_PCA_DF.iloc[i, 0], brom_PCA_DF.iloc[i,1], alpha = 0.34,
#                     c=brom_PCA_DF['color'][i], marker=brom_PCA_DF['shape'][i], 
#                     edgecolors='black', linewidths=1, s=100)
#     elif brom_PCA_DF['Pathway'][i]=='C3-CAM':
#         ax0.scatter(brom_PCA_DF.iloc[i, 0], brom_PCA_DF.iloc[i,1],
#                     c=brom_PCA_DF['color'][i], marker='*', 
#                     edgecolors='black', linewidths=1, s=300)
#     else:
#         ax0.scatter(brom_PCA_DF.iloc[i, 0], brom_PCA_DF.iloc[i,1], alpha = 0.34,
#                     c=brom_PCA_DF['color'][i], marker=brom_PCA_DF['shape'][i], 
#                     edgecolors='black', linewidths=1, s=100)
        
for i in range(len(logbrom_PCA_DF)):
    if logbrom_PCA_DF['Pathway'][i]=='CAM':
        ax1.scatter(logbrom_PCA_DF.iloc[i, 0], logbrom_PCA_DF.iloc[i,1], alpha = 0.5,
                    c=logbrom_PCA_DF['color'][i], marker=logbrom_PCA_DF['shape'][i], 
                    edgecolors='black', linewidths=1, s=100)
    elif logbrom_PCA_DF['Pathway'][i]=='C3-CAM':
        ax1.scatter(logbrom_PCA_DF.iloc[i, 0], logbrom_PCA_DF.iloc[i,1],
                    c=logbrom_PCA_DF['color'][i], marker='*', 
                    edgecolors='black', linewidths=1, s=300)
    else:
        ax1.scatter(logbrom_PCA_DF.iloc[i, 0], logbrom_PCA_DF.iloc[i,1], alpha = 0.5,
                    c=logbrom_PCA_DF['color'][i], marker=logbrom_PCA_DF['shape'][i], 
                    edgecolors='black', linewidths=1, s=100)
        
# ax0.set_xlabel("PC1("+str('{:.4}'.format(brom_pca_config.explained_variance_ratio_[0]))+")", size=14)
# ax0.set_ylabel("PC2("+str('{:.4}'.format(brom_pca_config.explained_variance_ratio_[1]))+")", size=14)
ax1.set_xlabel("PC1("+str('{:.4}'.format(logbrom_pca_config.explained_variance_ratio_[0]))+")", size=14)
ax1.set_ylabel("PC2("+str('{:.4}'.format(logbrom_pca_config.explained_variance_ratio_[1]))+")", size=14)
    
red_patch = mpatches.Patch(color='red', label='C3-CAM')
green_patch = mpatches.Patch(color='green', label='C3')
blue_patch = mpatches.Patch(color='blue', label='CAM')

# ax0.legend(handles=[green_patch, blue_patch, red_patch], fontsize=12, frameon=True, )
ax1.legend(handles=[green_patch, blue_patch, red_patch], fontsize=16, frameon=True, )

# ax0.set_title('Non-transformed', size=14)
# ax1.set_title('Log-transformed', size=14)
plt.tight_layout()
# plt.savefig("/Users/iangilman/Downloads/brom_logpca.pdf", tranparent=True, dpi=300, bbox_inches="tight");

# %% [markdown]
# Above, triangles are CAM, circles are C3, and the stars are C3-CAM intermediates (the star is hard to pick out because its in the center of the densest area of the plot). Qualitatively, the log-transformed PCA is close to Male's PCA, although his addition of convex hulls makes it harder to see.
#
# Now to use support vector machines (SVM) and random forests (RF) to classify C3, CAM, and C3-CAM. Basically, SVMs apply transformations to our data (observations) and look for breaks between the classes in multidimensional space. Support vectors are built to maximize the buffer space around those breaks for each observation. We'll use a linear model for transformations, but nonlinear models can be applied.
#
# Random forests also look for breaks between classes, but in a different way. RFs use a set of decision trees that step through our features one by one, often revisiting the same feature more than once, each time creating a break that separates the most observations into their respective classifications until all observations have been sorted.
#
# Before we use our real data, I'll show two cases where these techniques outperform traditional methods like PCA.

# %% [markdown]
# ## Support vector machines (SVMs)
# ### An example
# Here is a quick example to demonstrate the utility of support vector machines. Suppose we have red and blue classes as distributed below.

# %%
circledata = pd.DataFrame()
circledata['x'] = np.random.uniform(low=-1.0, high=1.0, size=1000)
circledata['y'] = np.random.uniform(low=-1.0, high=1.0, size=1000)
circleclasses = []
for i, row in circledata.iterrows():
    if -(row['x']**2+row['y']**2)<-0.25:
        circleclasses.append('red')
    else:
        circleclasses.append('blue')
circledata['color'] = circleclasses

twolinedata = pd.DataFrame()
twolinedata['x'] =  list(np.linspace(start=-5.0, stop=5.0, num=500, ) + np.random.normal(scale=1, size=500))*2
np.random.seed(1)
twolinedata['y'] = list(np.linspace(start=-5.0, stop=5.0, num=500) + np.random.normal(scale=1, size=500))*2
twolinedata['z'] =  list(np.linspace(start=0.0, stop=0.3, num=500)) + list(np.linspace(start=0.2, stop=0.5, num=500))
twolineclasses = []
for i, row in twolinedata.iterrows():
    if i<500:
        twolineclasses.append('red')
    else:
        twolineclasses.append('blue')
twolinedata['color'] = twolineclasses

# %%
fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot(1,2,1)

ax.scatter(circledata['x'], circledata['y'], c=circledata['color'], marker='.')
ax.set_xlabel("X")
ax.set_ylabel("Y")

ax1 = fig.add_subplot(1,2,2, projection='3d')
ax1.scatter(twolinedata['x'], twolinedata['y'], twolinedata['z'], c=twolinedata['color'], alpha=0.5)
ax1.set_xlabel("X")
ax1.set_ylabel("Y")
ax1.set_zlabel("Z")

ax.set_title("Circle", size=14)
ax1.set_title("Two lines", size=14)
plt.tight_layout();

# %% [markdown]
# In the case of the circle we can easily pick out our classes but there are no gaps between them. In the case of the two lines it seems like we we can both easily distinguish them and separate them.

# %%
circle_PCA_config = PCA(n_components=2)
circle_temp = circledata[['x','y']]
circle_PCA = circle_PCA_config.fit(circle_temp).transform(circle_temp)

twoline_PCA_config = PCA(n_components=2)
twoline_temp = twolinedata[['x','y','z']]
twoline_PCA = twoline_PCA_config.fit(twoline_temp).transform(twoline_temp)

print('Explained variance ratio (first two components): {}'.format(circle_PCA_config.explained_variance_ratio_))
print('Explained variance ratio (first two components): {}'.format(twoline_PCA_config.explained_variance_ratio_))
# Out:
# Explained variance ratio (first two components): [ 0.51524806  0.48475194]
# Explained variance ratio (first two components): [ 0.94451173  0.05494134]

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(8, 4))

ax0.scatter(x=circle_PCA[:,0], y=circle_PCA[:,1], c=circledata['color'], alpha=0.5, marker='.')
ax1.scatter(x=twoline_PCA[:,0], y=twoline_PCA[:,1], c=twolinedata['color'], alpha=0.5, marker='.')
        
ax0.set_xlabel("PC1("+str('{:.4}'.format(circle_PCA_config.explained_variance_ratio_[0]))+")", size=14)
ax0.set_ylabel("PC2("+str('{:.4}'.format(circle_PCA_config.explained_variance_ratio_[1]))+")", size=14)
ax1.set_xlabel("PC1("+str('{:.4}'.format(twoline_PCA_config.explained_variance_ratio_[0]))+")", size=14)
ax1.set_ylabel("PC2("+str('{:.4}'.format(twoline_PCA_config.explained_variance_ratio_[1]))+")", size=14)

ax0.set_title('Circle', size=14)
ax1.set_title('Two lines', size=14)

plt.tight_layout();

# %% [markdown]
# With PCA we can explain much of the variance, but we still haven't made progress in separating our two classes in the case of the circle and the two lines have completely collapsed on each other in PC-space. In the latter case we know that most of the variation in the data is not correlated with our classes, and we are basically looking at a projection onto the X-Y plane.
#
# In the two lines we know that if we leave our data in higher dimensions then we should be able to draw planes between the two classes. We can also transform our circle data with second degree polynomial into a paraboloid (visualization below), which should allow us to split it appart with a single plane.

# %%
# Create SVM classification object with 2nd degree polynomial kernel
circle_svm_clf = svm.SVC(kernel='poly',degree=2, random_state=0)

# Split data into training and testing
circle_train_X, circle_test_X, circle_train_y, circle_test_y = train_test_split(
    circledata[['x','y']], circledata['color'], test_size=0.25, random_state=0)

# %%
# Fit model
circle_svm_clf.fit(circle_train_X, circle_train_y)
# Cross validate and record score of test
circle_svm_crossval = cross_val_score(circle_svm_clf, circledata[['x','y']], circledata['color'], n_jobs=-1)
# Cross validate and record predictions
circle_svm_preds = cross_val_predict(circle_svm_clf, circledata[['x','y']], circledata['color'], n_jobs=-1)
circle_svm_crosstab = pd.crosstab(circledata['color'], circle_svm_preds, rownames=['Actual'], colnames=['Predicted'])
print("Cross validation accuracy: %0.3f (+/- %0.3f)" % (circle_svm_crossval.mean(), circle_svm_crossval.std() * 2))
circle_svm_crosstab
# Out:
# Cross validation accuracy: 0.976 (+/- 0.038)
# Predicted  blue  red
# Actual
# blue        176   21
# red           3  800

# %%
fig = plt.figure(figsize=(8,4))

ax = fig.add_subplot(1,2,1)
ax.set_xlim([-1,1])
ax.set_ylim([-1,1])
plot_svc_decision_function(circle_svm_clf, ax=ax)
ax.scatter(x=circledata['x'], y=circledata['y'], c=circledata['color'], alpha=0.5, marker='.')
ax.set_xlabel("X", size=14)
ax.set_ylabel("Y", size=14)
ax.set_xticklabels([''])
ax.set_yticklabels([''])

plt3d = fig.add_subplot(1,2,2, projection='3d')
circledata['z'] = -(circledata['x']**2+circledata['y']**2)
plt3d.scatter(circledata['x'], circledata['y'], circledata['z'], c=circledata['color'], alpha=0.5, marker='.')

plt3d.set_xlim([-1,1])
plt3d.set_ylim([-1,1])
plt3d.set_xticklabels([''])
plt3d.set_yticklabels([''])
plt3d.set_zticklabels([''])
plt3d.set_xlabel('X', size=14)
plt3d.set_ylabel('Y', size=14)
plt3d.set_zlabel('Z', size=14)
plt3d.view_init(elev=1, azim=60)

ax.set_title('Decision boundary and SVs', size=14)
plt3d.set_title('3D projection of\ncircle data', size=14)

plt.tight_layout();

# %% [markdown]
# Now we can see the decision boundary (left) along with a projection with our paraboloid that shows us one way we could imagine separating the circle data by increasing the dimensionality and finding a plane.

# %% [markdown]
# ## ...back to bromeliads
# Unfortunately, because we only have a single C3-CAM species we will not be able to do any classificication with this type of photosynthensis, so we will drop it from our dataset.

# %%
broms_2018 = broms_2018[broms_2018['Pathway']!='C3-CAM']
logbroms_2018 = logbroms_2018[logbroms_2018['Pathway']!='C3-CAM']

# %%
# Divide into training and testing data (X's) and responses (y's) 
brom_train_X, brom_test_X, brom_train_y, brom_test_y = train_test_split(
    broms_2018[brom_features], broms_2018['Pathway'], test_size=0.25, random_state=0)

# Create and SVM classification object 
brom_svm_clf = svm.SVC(kernel='linear')

# %% [markdown]
# Finally, we can fit our model, test its accuracy with cross-validation (number of cross-validations set with the `cv` flag), and print the confusion matrix from another round of cross-validation. _Note that the_ `n_jobs=-1` _option parallelizes the model and cross-validation, which, if you're using a Jupyter Notebook, will require you to interrupt the kernel for every worker that is spawned_.

# %%
brom_svm_crossval = cross_val_score(brom_svm_clf, broms_2018[brom_features], broms_2018['Pathway'], 
                                    cv=5, n_jobs=-1)
brom_svm_preds = cross_val_predict(brom_svm_clf, broms_2018[brom_features], broms_2018['Pathway'], 
                                   cv=5, n_jobs=-1)
brom_svm_crosstab = pd.crosstab(broms_2018['Pathway'], brom_svm_preds, 
                                rownames=['Actual'], colnames=['Predicted'])

print("Cross-validation accuracy: {:.3} (+/- {:.3})".format(
    brom_svm_crossval.mean(), brom_svm_crossval.std()*2))
brom_svm_crosstab
# Out:
# Cross-validation accuracy: 0.951 (+/- 0.0628)
# Predicted  C3  CAM
# Actual
# C3         60    1
# CAM         5   56

# %% [markdown]
# Our cross-validation accuracy is high and we see that we more often misclassify CAM taxa as C3 than vice versa.

# %%
logbrom_train_X, logbrom_test_X, logbrom_train_y, logbrom_test_y = train_test_split(
    logbroms_2018[brom_features], logbroms_2018['Pathway'], test_size=0.25, random_state=0)
logbrom_svm_clf = svm.SVC(kernel='linear')

# %%
logbrom_svm_crossval = cross_val_score(logbrom_svm_clf, logbroms_2018[brom_features], logbroms_2018['Pathway'], 
                                       cv=5, n_jobs=-1)
logbrom_svm_preds = cross_val_predict(logbrom_svm_clf, logbroms_2018[brom_features], logbroms_2018['Pathway'], 
                                      cv=5, n_jobs=-1)
logbrom_svm_crosstab = pd.crosstab(logbroms_2018['Pathway'], logbrom_svm_preds, 
                                   rownames=['Actual'], colnames=['Predicted'])

print("Cross-validation accuracy: {:.3} (+/- {:.3})".format(
    logbrom_svm_crossval.mean(), logbrom_svm_crossval.std()*2))
logbrom_svm_crosstab
# Out:
# Cross-validation accuracy: 0.976 (+/- 0.0398)
# Predicted  C3  CAM
# Actual
# C3         59    2
# CAM         1   60

# %% [markdown]
# We achieve slightly higher accuracy with lower variance when using the log-transformed data.
#
# Our PCA and scatter plots of the raw data above show that the two main classes (C3 and CAM) are fairly spread out, and the raw data show that these classes aren't always spread along the main axes of variation, which is why this type of classification out-performs separation with PCA.
#
# ## Random Forest
# ### raw data

# %%
# Create a random forest Classifier.
brom_rf_clf = RandomForestClassifier(n_jobs=-1)
# Repeat cross validation as before
brom_rf_crossval = cross_val_score(brom_rf_clf, broms_2018[brom_features], broms_2018['Pathway'], 
                                   cv=5, n_jobs=-1)
brom_rf_preds = cross_val_predict(brom_rf_clf, broms_2018[brom_features], broms_2018['Pathway'], 
                                  cv=5, n_jobs=-1)
brom_rf_crosstab = pd.crosstab(broms_2018['Pathway'], brom_rf_preds, rownames=['Actual'], colnames=['Predicted'])

print("Cross-validation accuracy: {:.3} (+/- {:.3})".format(brom_rf_crossval.mean(), brom_rf_crossval.std()*2))
brom_rf_crosstab
# Out:
# Cross-validation accuracy: 0.847 (+/- 0.211)
# Predicted  C3  CAM
# Actual
# C3         49   12
# CAM         7   54

# %% [markdown]
# Our RF classifier performed just as well as our SVMs, but the variance is much higher. A nice feature of randon forests is that we can look directly at how important each feature was in making decisions.

# %%
brom_rf_importance = brom_rf_clf.fit(brom_train_X, brom_train_y).feature_importances_
brom_importance = pd.DataFrame(zip(brom_train_X, brom_rf_importance), columns=['feature', 'importance'])
brom_importance.sort_values(by='importance', ascending=False)
# Out:
#                               feature  importance
# 1            chlorenchyma_diameter_um    0.397286
# 3  chlorenchyma_vertical_thickness_um    0.283521
# 5                   leaf_thickness_um    0.146067
# 2      chlorenchyma_hydrenchyma_ratio    0.085509
# 0                air_channel_area_um2    0.063099
# 4   hydrenchyma_vertical_thickness_um    0.024518

# %% [markdown]
# Chlorenchyma diameter was most important, and leaf thickness helped to round over 70% of the importance.
# ### log-transformed data

# %%
# Create a random forest Classifier.
logbrom_rf_clf = RandomForestClassifier(n_jobs=-1)
# Repeat cross validation as before
logbrom_rf_crossval = cross_val_score(logbrom_rf_clf, logbroms_2018[brom_features], logbroms_2018['Pathway'], 
                                      cv=5, n_jobs=-1)
logbrom_rf_preds = cross_val_predict(logbrom_rf_clf, logbroms_2018[brom_features], logbroms_2018['Pathway'], 
                                     cv=5, n_jobs=-1)
logbrom_rf_crosstab = pd.crosstab(logbroms_2018['Pathway'], logbrom_rf_preds, 
                                  rownames=['Actual'], colnames=['Predicted'])

print("Cross-validation accuracy: {:.3} (+/- {:.3})".format(
    logbrom_rf_crossval.mean(), logbrom_rf_crossval.std()*2))
logbrom_rf_crosstab
# Out:
# Cross-validation accuracy: 0.874 (+/- 0.348)
# Predicted  C3  CAM
# Actual
# C3         50   11
# CAM         5   56

# %%
logbrom_rf_importance = logbrom_rf_clf.fit(logbrom_train_X, logbrom_train_y).feature_importances_
logbrom_importance = pd.DataFrame(zip(logbrom_train_X, logbrom_rf_importance), columns=['feature', 'importance'])
logbrom_importance.sort_values(by='importance', ascending=False)
# Out:
#                               feature  importance
# 1            chlorenchyma_diameter_um    0.327359
# 5                   leaf_thickness_um    0.242615
# 3  chlorenchyma_vertical_thickness_um    0.196681
# 2      chlorenchyma_hydrenchyma_ratio    0.123886
# 0                air_channel_area_um2    0.070403
# 4   hydrenchyma_vertical_thickness_um    0.039056

# %% [markdown]
# Interestingly, our accuracy went down slighty while the variance increased in both RFs. The order of importance changed slightly when we transformed the data, but the same two top features (in the same order) still comprise over 70% of the importance.
#
# Now we can look at a slighty smaller dataset with roughly equal parts C3, CAM, and C3-CAM in Orchids ([Silvera et al. 2005](http://www.publish.csiro.au/FP/FP04179)).

# %% [markdown]
# # Silvera et al. (2005): Orchids
# ### raw data

# %%
orchid_2005 = cam_db[cam_db['Source']=='Silvera et al (2005)'].reset_index(drop=True)
orchid_2005.head()
# Out:
#         Family       Subfamily       Tribe     Subtribe      Genus  \
# 0  Orchidaceae  Epidendroideae  Cymbidieae   Oncidiinae        Ada
# 1  Orchidaceae             NaN         NaN          NaN  Ancipitia
# 2  Orchidaceae  Epidendroideae  Arethuseae  Arethusinae   Arundina
# 3  Orchidaceae  Epidendroideae  Cymbidieae   Oncidiinae    Aspasia
# 4  Orchidaceae  Epidendroideae  Cymbidieae   Oncidiinae    Aspasia
#
#          Species Subspecies  BS_area_um2  FM_DM  FM_DM_sd  \
# 0        allenii        NaN          NaN    8.1       0.5
# 1  crocodiliceps        NaN          NaN    8.7       0.9
# 2   graminifolia        NaN          NaN    3.5       0.2
# 3  epidendroides        NaN          NaN    5.3       0.2
# 4    principissa        NaN          NaN    4.5       0.2
#
#            ...            transpiration_ratio  avg_elevation_m  LCCDM  SLAFM  \
# 0          ...                            NaN              NaN    NaN    NaN
# 1          ...                            NaN              NaN    NaN    NaN
# 2          ...                            NaN              NaN    NaN    NaN
# 3          ...                            NaN              NaN    NaN    NaN
# 4          ...                            NaN              NaN    NaN    NaN
#
#                  long_name  pct_night_C02  H+_ev_mumol_g-1_DW  \
# 0              Ada allenii            NaN                 NaN
# 1  Ancipitia crocodiliceps            NaN                 NaN
# 2    Arundina graminifolia            NaN                 NaN
# 3    Aspasia epidendroides            NaN                 NaN
# 4      Aspasia principissa            NaN                 NaN
#
#   H+_ev_mumol_g-1_DW_sd  H+_mo_mumol_g-1_DW  H+_mo_mumol_g-1_DW_sd
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                   NaN                 NaN                    NaN
# 3                   NaN                 NaN                    NaN
# 4                   NaN                 NaN                    NaN
#
# [5 rows x 53 columns]

# %%
db_info(orchid_2005, plt_missingdata=True, labels=True, fontsize=12)
# Out:
# The CAM database consists of:
# 	198 observations,
# 	1 families,
# 	2 subfamiles,
# 	6 tribes,
# 	12 subtribes,
# 	72 genera, and
# 	197 species from 1 publications.
# 0.641 of the data matrix is missing and
# 198 observations have known photosynthetic pathways.

# %%
orchid_features = ['FM_DM', 'SLA_cm2_g-1', 'leaf_thickness_um']
db_info(orchid_2005[orchid_features+['Pathway', 'long_name']], plt_missingdata=True, figsize=(3,3), labels=True, fontsize=12)
# Out:
# The CAM database consists of:
# 	198 observations,
# 	None families,
# 	None subfamiles,
# 	None tribes,
# 	None subtribes,
# 	None genera, and
# 	197 species from None publications.
# 0.0626 of the data matrix is missing and
# 198 observations have known photosynthetic pathways.

# %%
orchid_2005 = orchid_2005[orchid_features+['Pathway', 'long_name']]
orchid_2005.dropna(inplace=True)

# %% [markdown]
# After remove missing data we're left with 167 observations.

# %%
g = sns.pairplot(orchid_2005, hue="Pathway", markers='o')
g.fig.set_size_inches(7,6)
replacements = dict(zip(orchid_features ,['FM:DM ratio',
                                             'SLA (cm$^{2}\cdot g^{-1}$)',
                                             'Leaf thickness ($\mu$m)']))

for i in range(len(orchid_features)):
    for j in range(len(orchid_features)):
        xlabel = g.axes[i][j].get_xlabel()
        ylabel = g.axes[i][j].get_ylabel()
        if xlabel in replacements.keys():
            g.axes[i][j].set_xlabel(replacements[xlabel], size=12)
        if ylabel in replacements.keys():
            g.axes[i][j].set_ylabel(replacements[ylabel], size=12)

# %%
logorchid_2005 = orchid_2005[orchid_features].apply(np.log)
logorchid_2005['Pathway'] = orchid_2005['Pathway']

# %%
g = sns.pairplot(logorchid_2005, hue="Pathway", markers='o')
g.fig.set_size_inches(7,6)
replacements = dict(zip(orchid_features ,['FM:DM ratio',
                                          'SLA (cm$^{2}\cdot g^{-1}$)',
                                          'Leaf thickness ($\mu$m)']))

for i in range(len(orchid_features)):
    for j in range(len(orchid_features)):
        xlabel = g.axes[i][j].get_xlabel()
        ylabel = g.axes[i][j].get_ylabel()
        if xlabel in replacements.keys():
            g.axes[i][j].set_xlabel(replacements[xlabel], size=12)
        if ylabel in replacements.keys():
            g.axes[i][j].set_ylabel(replacements[ylabel], size=12)
# plt.savefig("/Users/iangilman/Downloads/orchid_log_pca.pdf", tranparent=True, dpi=300, bbox_inches="tight");

# %%
# Compute the correlation matrix
orchid_2005_corr = orchid_2005[orchid_features].corr()

# Generate a mask for the upper triangle
orchid_2005_mask = np.zeros_like(orchid_2005_corr, dtype=np.bool)
orchid_2005_mask[np.triu_indices_from(orchid_2005_mask)] = True

# Repeat for log-transformed
logorchid_2005_corr = logorchid_2005[orchid_features].corr()
logorchid_2005_mask = np.zeros_like(logorchid_2005_corr, dtype=np.bool)
logorchid_2005_mask[np.triu_indices_from(logorchid_2005_mask)] = True

# %%
fig, (ax0, ax1) = plt.subplots(1,2, figsize=(8, 4))

sns.heatmap(orchid_2005_corr, annot=True, mask=orchid_2005_mask, cmap="RdBu_r", center=0,
            square=True, linewidths=.5, cbar=False, ax=ax0)
sns.heatmap(logorchid_2005_corr, annot=True, mask=logorchid_2005_mask, cmap="RdBu_r", center=0,
            square=True, linewidths=.5, cbar=True, ax=ax1)

ax0.set_title('Non-transformed')
ax0.set_xticks([0.5, 1.5,])
ax0.set_yticks([2.5, 1.5])
ax0.set_yticklabels(['leaf thickness ($\mu$m)', 'SLA (cm$^2\cdot g^{-1}$)'], va='center')

ax1.set_title('Log-transformed')
ax1.set_xticks([0.5, 1.5,])
ax1.set_yticks([2.5, 1.5])
ax1.set_yticklabels(['leaf thickness ($\mu$m)', 'SLA (cm$^2\cdot g^{-1}$)'], va='center')

plt.tight_layout();

# %%
orchid_pca_config = PCA(n_components=2)
orchid_temp = orchid_2005[orchid_features]
orchid_PCA = orchid_pca_config.fit(orchid_temp).transform(orchid_temp)
print('Non-transformed explained variance (first two components): %s' % str(orchid_pca_config.explained_variance_ratio_))

logorchid_pca_config = PCA(n_components=2)
logorchid_temp = logorchid_2005[orchid_features]
logorchid_PCA = logorchid_pca_config.fit(logorchid_temp).transform(logorchid_temp)
print('Log-transformed explained variance (first two components): %s' % str(logorchid_pca_config.explained_variance_ratio_))
# Out:
# Non-transformed explained variance (first two components): [ 0.99676533  0.00323061]
# Log-transformed explained variance (first two components): [ 0.83818513  0.13227851]

# %% [markdown]
# As in the bromeliads, the amount of variance explained by the first two principal components is over 95%.

# %%
orchid_color_map = {'C3':'blue', 'C3-CAM':'green', 'CAM':'red'}

# %%
orchid_PCA_DF = pd.DataFrame(orchid_PCA, columns=['X', 'Y'])
orchid_PCA_DF['color'] = [orchid_color_map[pathway] for pathway in orchid_2005['Pathway']]

logorchid_PCA_DF = pd.DataFrame(logorchid_PCA, columns=['X', 'Y'])
logorchid_PCA_DF['color'] = [orchid_color_map[pathway] for pathway in logorchid_2005['Pathway']]

# %%
# fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(12, 6))
fig, ax1 = plt.subplots(figsize=(6, 6))

# for i in range(len(orchid_PCA_DF)):
#     ax0.scatter(orchid_PCA_DF.iloc[i, 0], orchid_PCA_DF.iloc[i,1], alpha = 0.5,
#                     c=orchid_PCA_DF['color'][i], edgecolors='black', linewidths=1, s=100)

for i in range(len(logorchid_PCA_DF)):
    ax1.scatter(logorchid_PCA_DF.iloc[i, 0], logorchid_PCA_DF.iloc[i,1], alpha = 0.5,
                    c=logorchid_PCA_DF['color'][i], edgecolors='black', linewidths=1, s=100)

# ax0.set_xlabel("PC1("+str('{:.4}'.format(orchid_pca_config.explained_variance_ratio_[0]))+")", size=14)
# ax0.set_ylabel("PC2("+str('{:.4}'.format(orchid_pca_config.explained_variance_ratio_[1]))+")", size=14)
ax1.set_xlabel("PC1("+str('{:.4}'.format(logorchid_pca_config.explained_variance_ratio_[0]))+")", size=14)
ax1.set_ylabel("PC2("+str('{:.4}'.format(logorchid_pca_config.explained_variance_ratio_[1]))+")", size=14)
    
red_patch = mpatches.Patch(color='red', label='CAM')
green_patch = mpatches.Patch(color='green', label='C3-CAM')
blue_patch = mpatches.Patch(color='blue', label='C3')

# ax0.legend(handles=[blue_patch, green_patch, red_patch], fontsize=12, frameon=True, )
ax1.legend(handles=[blue_patch, green_patch, red_patch], fontsize=16, frameon=True)

# ax0.set_title('Non-transformed', size=14)
# ax1.set_title('Log-transformed', size=14)

plt.tight_layout()
# plt.savefig("/Users/iangilman/Downloads/orchid_logpca.pdf", tranparent=True, dpi=300, bbox_inches="tight");

# %% [markdown]
# ## Support vector machine
# ### raw data

# %%
# Uncomment to remove C3-CAM for testing 2-label classification
# orchid_2005 = orchid_2005.loc[orchid_2005['Pathway']!='C3-CAM']
# log_orchid_2005 = log_orchid_2005.loc[log_orchid_2005['Pathway']!='C3-CAM']

# %% [markdown]
# #### A note on multi-class SVM
# Support vector machines are inherently 2 class methods. There are two main ways we can get around this when we want to have multiple classes (e.g. C3, CAM, and C3-CAM): one-vs-one and one-vs-all classification. In one-vs-one we train a classifier for _each pair of classes_, while in one-vs-all we train a classifier for _each class against all other classes_. One-vs-one tends to handle imbalanced class sizes (as we have here; ~twice as many C3 as either CAM or C3-CAM), but comes at a larger computational cost. We'll use one-vs-one here, which is the default for `svm.SVC`, because the computational burden isn't so high and our data are fairly imbalanced.

# %%
# Divide into training and testing data (X's) and responses (y's) 
orchid_train_X, orchid_test_X, orchid_train_y, orchid_test_y = train_test_split(
    orchid_2005[orchid_features], orchid_2005['Pathway'], test_size=0.25, random_state=0)

# Create and SVM classification object 
orchid_svm_clf = svm.SVC(kernel='linear')

# %%
orchid_svm_crossval = cross_val_score(orchid_svm_clf, orchid_2005[orchid_features], orchid_2005['Pathway'], 
                                      cv=5, n_jobs=-1)
orchid_svm_preds = cross_val_predict(orchid_svm_clf, orchid_2005[orchid_features], orchid_2005['Pathway'], 
                                     cv=5, n_jobs=-1)
orchid_svm_crosstab = pd.crosstab(orchid_2005['Pathway'], orchid_svm_preds, 
                                  rownames=['Actual'], colnames=['Predicted'])
print("Cross-validation accuracy: %0.3f (+/- %0.3f)" % (orchid_svm_crossval.mean(), orchid_svm_crossval.std()*2))
orchid_svm_crosstab
# Out:
# Cross-validation accuracy: 0.665 (+/- 0.109)
# Predicted  C3  CAM
# Actual
# C3         74    8
# C3-CAM     39    2
# CAM         7   37

# %% [markdown]
# Our accuracy is pretty low, and we didn't predict a single observation to be C3-CAM&mdash;almost were classified as C3.

# %% [markdown]
# ### log-transformed data

# %%
# Divide into training and testing data (X's) and responses (y's) 
logorchid_train_X, logorchid_test_X, logorchid_train_y, logorchid_test_y = train_test_split(
    logorchid_2005[orchid_features], logorchid_2005['Pathway'], test_size=0.25, random_state=0)

# Create and SVM classification object 
logorchid_svm_clf = svm.SVC(kernel='linear')

# %%
logorchid_svm_crossval = cross_val_score(logorchid_svm_clf, logorchid_2005[orchid_features],
                                         logorchid_2005['Pathway'], cv=5, n_jobs=-1)
logorchid_svm_preds = cross_val_predict(logorchid_svm_clf, logorchid_2005[orchid_features], 
                                     logorchid_2005['Pathway'], cv=5, n_jobs=-1)
logorchid_svm_crosstab = pd.crosstab(logorchid_2005['Pathway'], logorchid_svm_preds, 
                                  rownames=['Actual'], colnames=['Predicted'])
print("Cross-validation accuracy: %0.3f (+/- %0.3f)" % (logorchid_svm_crossval.mean(), 
                                                        logorchid_svm_crossval.std()*2))
logorchid_svm_crosstab
# Out:
# Cross-validation accuracy: 0.630 (+/- 0.127)
# Predicted  C3  CAM
# Actual
# C3         69   13
# C3-CAM     39    2
# CAM         8   36

# %% [markdown]
# Neither of our SVMs are very good at classifying the three phenotypes. While there are most likely improvements we can make to the model and model fitting, with only 40-50 observations of each class we simply may not have enough power to classify these phenotypes.
#
# Next we'll try random forests again, which _are_ inherently multi-class.

# %% [markdown]
# ## Random forest

# %%
orchid_rf_clf = RandomForestClassifier(n_jobs=-1)
# Repeat cross validation as before
orchid_rf_crossval = cross_val_score(orchid_rf_clf, orchid_2005[orchid_features], orchid_2005['Pathway'], 
                                   cv=5, n_jobs=-1)
orchid_rf_preds = cross_val_predict(orchid_rf_clf, orchid_2005[orchid_features], orchid_2005['Pathway'], 
                                  cv=5, n_jobs=-1)
orchid_rf_crosstab = pd.crosstab(orchid_2005['Pathway'], orchid_rf_preds, rownames=['Actual'], colnames=['Predicted'])

print("Cross-validation accuracy: {:.3} (+/- {:.3})".format(orchid_rf_crossval.mean(), orchid_rf_crossval.std()*2))
orchid_rf_crosstab
# Out:
# Cross-validation accuracy: 0.63 (+/- 0.168)
# Predicted  C3  C3-CAM  CAM
# Actual
# C3         60      15    7
# C3-CAM     32       7    2
# CAM         5       1   38

# %%
orchid_rf_importance = orchid_rf_clf.fit(orchid_train_X, orchid_train_y).feature_importances_
orchid_importance = pd.DataFrame(zip(orchid_train_X, orchid_rf_importance), columns=['feature', 'importance'])
orchid_importance.sort_values(by='importance', ascending=False)
# Out:
#              feature  importance
# 1        SLA_cm2_g-1    0.342524
# 0              FM_DM    0.330600
# 2  leaf_thickness_um    0.326876

# %%
logorchid_rf_clf = RandomForestClassifier(n_jobs=-1)
# Repeat cross validation as before
logorchid_rf_crossval = cross_val_score(logorchid_rf_clf, logorchid_2005[orchid_features], 
                                        logorchid_2005['Pathway'], cv=5, n_jobs=-1)
logorchid_rf_preds = cross_val_predict(logorchid_rf_clf, logorchid_2005[orchid_features], 
                                       logorchid_2005['Pathway'], cv=5, n_jobs=-1)
logorchid_rf_crosstab = pd.crosstab(logorchid_2005['Pathway'], logorchid_rf_preds, 
                                    rownames=['Actual'], colnames=['Predicted'])

print("Cross-validation accuracy: {:.3} (+/- {:.3})".format(logorchid_rf_crossval.mean(), logorchid_rf_crossval.std()*2))
logorchid_rf_crosstab
# Out:
# Cross-validation accuracy: 0.625 (+/- 0.148)
# Predicted  C3  C3-CAM  CAM
# Actual
# C3         56      20    6
# C3-CAM     28      10    3
# CAM         5       1   38

# %% [markdown]
# Our RF classifiers have increased training accuracy but about the same testing accuracy. This is symptomatic of a lack of data, specifically for training. We are able to build an accurate classifier during training but that classifier has not seen enough variation to reliably classify new points that it encounters during testing.

# %% [markdown]
# # Trying with whole CAM database

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(12,4))

ax0.hist(x=cam_db[cam_db['Pathway']=='CAM']['dC13'].dropna(), edgecolor='blue',
         linewidth=2, color='blue', alpha=0.5, bins=15)
ax0.hist(x=cam_db[cam_db['Pathway']=='C3']['dC13'].dropna(), edgecolor='orange', 
         linewidth=2, color='orange', alpha=0.5, bins=15)
ax0.hist(x=cam_db[cam_db['Pathway']=='C3-CAM']['dC13'].dropna(), edgecolor='red', 
         linewidth=2, color='red', alpha=0.5, bins=10)
ax0.hist(x=cam_db[cam_db['Pathway']=='C4']['dC13'].dropna(), edgecolor='green', 
         linewidth=2, color='green', alpha=0.5, bins=10)

ax1.hist(x=cam_db[cam_db['Pathway'].isin(['C3', 'C4', 'CAM', 'C3-CAM', 'C3-C4'])]['dC13'].dropna(), 
         fc=(1, 1, 1, 1), edgecolor='black', linewidth=2, alpha=1, bins=25)
ax1.hist(x=cam_db[cam_db['Pathway'].isnull()]['dC13'].dropna(), color='grey', alpha=0.25, bins=50)

orange_patch = mpatches.Patch(color='orange', alpha=0.5, label='C3', )
green_patch = mpatches.Patch(color='green', alpha=0.5, label='C4')
red_patch = mpatches.Patch(color='red', alpha=0.5, label='C3-CAM')
blue_patch = mpatches.Patch(color='blue', alpha=0.5, label='CAM')

ax0.legend(handles=[orange_patch, green_patch, red_patch, blue_patch], fontsize=12, frameon=True, )
ax0.set_xlim([-40, -5])
ax0.set_xlabel('$\delta$C$^{13}$', size=14)

grey_patch = mpatches.Patch(color='grey', alpha=0.5, label='Unknown pathway')
black_patch = mpatches.Patch(facecolor='white', edgecolor='black', linewidth=1, label='Known pathway')

ax1.legend(handles=[grey_patch, black_patch], fontsize=12, frameon=True, )
ax1.set_xlim([-40, -5])
ax1.set_xlabel('$\delta$C$^{13}$', size=14);

# %% [markdown]
# Because most taxa have more than one entry, I'll collapse everything by species by filling in missing data and averaging when possible.

# %%
DF = cam_db.copy()

# %%
db_info(DF)
# Out:
# The CAM database consists of:
# 	5521 observations,
# 	57 families,
# 	12 subfamiles,
# 	13 tribes,
# 	22 subtribes,
# 	434 genera, and
# 	3559 species from 61 publications.
# 0.823 of the data matrix is missing and
# 761 observations have known photosynthetic pathways.

# %%
metadata_keys = ['Family', 'Subfamily', 'Tribe', 'Subtribe', 'Genus', 'Species', 'Subspecies', 'Source']
categorical_keys = ['Habit', 'Pathway', 'dH+_significance']
quantitative_keys = list(set(DF.columns)-set(metadata_keys)-set(categorical_keys))

# %%
DF2=DF.copy()

# %%
def data_fill_modes(DF, group, to_fill, verbose=False):
    
    # Create a copy to prevent bias after randomly choosing among responses
    copy = DF.copy()
    fill_dict={}
    # Loop over categories
    for cat in to_fill:
        filled_holes=0
        # Create temporary dataframe with category modes
        temp = modes(df=DF, key_cols=[group], value_col=cat, count_col='count')
        for index, row in copy.iterrows():
            taxon = copy.loc[index, group]
            # Skip unidentified taxa
            if taxon.lower() in ['species', 'sp', 'spp', 'spec', 'sp.', 'spp.', 'spec.']:
                if verbose: print("UH OH. UNIDENTIFIED TAXON: {}".format(taxon))
                continue
            # Only fill if current value is missing
            current = copy.loc[index, cat]
            if check_nan(current):
                if verbose: print("Found a hole in {}".format(taxon))
                if verbose: print(taxon, current)
                # Only fill if we have responses
                try: 
                    responses = temp.loc[temp[group]==taxon][cat]
                    if verbose: print("Found modes for {}".format(taxon))
                    # Take random draw if multiple modes
                    if len(responses)>1:
                        if verbose: print("Found more than one response: {}".format(responses))
                        response = np.random.choice(responses, size=1)[0]
                        filled_holes+=1
                    else:
                        if verbose: print("Found one response: {}".format(responses))
                        response = responses[0]
                        filled_holes+=1
                    if verbose: print(taxon, response)
                    if verbose: 
                        print("\tHOLE FILLED")
                except IndexError:
                    if verbose: print("Found no responses for {}".format(taxon))
                    response = np.NaN
                    if verbose: print("\t\tCANT FILL HOLE")
                copy.loc[index, cat] = response
        fill_dict[cat] = filled_holes
    if verbose: print fill_dict
    return copy

# %%
data_fill_modes(cam_db, group='Species', to_fill=['Pathway'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-f7f932cbd6dc> in <module>()
# ----> 1 data_fill_modes(cam_db, group='Species', to_fill=['Pathway'])
#
# <ipython-input-31-322cb3a1a40b> in data_fill_modes(DF, group, to_fill, verbose)
#       8         filled_holes=0
#       9         # Create temporary dataframe with category modes
# ---> 10         temp = modes(df=DF, key_cols=[group], value_col=cat, count_col='count')
#      11         for index, row in copy.iterrows():
#      12             taxon = copy.loc[index, group]
#
# NameError: global name 'modes' is not defined

# %%
db_info(cam_db)
# Out:
# The CAM database consists of:
# 	5521 observations,
# 	57 families,
# 	12 subfamiles,
# 	13 tribes,
# 	22 subtribes,
# 	434 genera, and
# 	3559 species from 61 publications.
# 0.823 of the data matrix is missing and
# 761 observations have known photosynthetic pathways.

# %%
DF = data_fill_modes(DF=cam_db, group='Genus', to_fill=['Pathway'], verbose=False)

# %%
drop_ambig(DF, rank='Genus')
# Out:
#             Family        Subfamily       Tribe        Subtribe  \
# 0      Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 1      Orchidaceae              NaN         NaN             NaN
# 2      Orchidaceae   Epidendroideae  Arethuseae     Arethusinae
# 3      Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 4      Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 5      Orchidaceae   Epidendroideae  Calypsoeae       Laeliinae
# 6      Orchidaceae   Epidendroideae  Calypsoeae       Laeliinae
# 7      Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 8      Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 9      Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 10     Orchidaceae              NaN         NaN             NaN
# 11     Orchidaceae              NaN         NaN             NaN
# 12     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 13     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 14     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 15     Orchidaceae   Epidendroideae  Calypsoeae       Laeliinae
# 16     Orchidaceae              NaN         NaN             NaN
# 17     Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 18     Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 19     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 20     Orchidaceae   Epidendroideae  Cymbidieae   Zygopetalinae
# 21     Orchidaceae   Epidendroideae  Cymbidieae  Coeliopsidinae
# 22     Orchidaceae   Epidendroideae  Cymbidieae    Stanhopeinae
# 23     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 24     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 25     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 26     Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 27     Orchidaceae   Epidendroideae  Cymbidieae   Zygopetalinae
# 28     Orchidaceae   Epidendroideae  Cymbidieae   Zygopetalinae
# 29     Orchidaceae   Epidendroideae  Calypsoeae       Laeliinae
# ...            ...              ...         ...             ...
# 5491  Bromeliaceae  Pitcairnioideae         NaN             NaN
# 5492  Bromeliaceae  Pitcairnioideae         NaN             NaN
# 5493  Bromeliaceae  Pitcairnioideae         NaN             NaN
# 5494  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5495  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5496  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5497  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5498  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5499  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5500  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5501  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5502  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5503  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5504  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5505  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5506  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5507  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5508  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5509  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5510  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5511  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5512  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5513  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5514  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5515  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5516  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5517  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5518  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5519  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5520  Bromeliaceae  Tillandsioideae         NaN             NaN
#
#                Genus         Species        Subspecies  BS_area_um2  FM_DM  \
# 0                Ada         allenii               NaN          NaN    8.1
# 1          Ancipitia   crocodiliceps               NaN          NaN    8.7
# 2           Arundina    graminifolia               NaN          NaN    3.5
# 3            Aspasia   epidendroides               NaN          NaN    5.3
# 4            Aspasia     principissa               NaN          NaN    4.5
# 5         Brassavola         acaulis               NaN          NaN   16.9
# 6         Brassavola          nodosa               NaN          NaN   12.5
# 7            Brassia       arcuigera               NaN          NaN    5.3
# 8            Brassia         caudata               NaN          NaN    5.5
# 9            Brassia       verrucosa       gireoudiana          NaN    6.5
# 10          Brenesia       johnsonii               NaN          NaN    8.4
# 11          Brenesia     lappiformis               NaN          NaN    8.8
# 12         Catasetum         bicolor               NaN          NaN    5.9
# 13         Catasetum       maculatum               NaN          NaN    5.0
# 14         Catasetum    viridiflavum               NaN          NaN    6.0
# 15          Cattleya         dowiana               NaN          NaN    9.9
# 16       Chelyorchis       ampliatum               NaN          NaN    7.6
# 17      Cischweinfia       dasyandra               NaN          NaN    6.1
# 18      Cischweinfia         pusilla               NaN          NaN    7.1
# 19          Clowesia    warscewiczii               NaN          NaN    5.8
# 20      Cochleanthes       aromatica               NaN          NaN    5.9
# 21        Coeliopsis    hyacinthosma               NaN          NaN    3.7
# 22        Coryanthes      hunteriana               NaN          NaN    5.8
# 23         Cycnoches          aureum               NaN          NaN    5.4
# 24         Cycnoches      guttulatum               NaN          NaN    NaN
# 25         Cycnoches    warscewiczii               NaN          NaN    4.8
# 26    Cyrtochiloides    ochmatochila               NaN          NaN    5.9
# 27           Dichaea      dammeriana               NaN          NaN    5.5
# 28           Dichaea  fragrantissima               NaN          NaN    6.2
# 29        Dimerandra      emarginata               NaN          NaN    5.3
# ...              ...             ...               ...          ...    ...
# 5491      Pitcairnia         arcuata               NaN          NaN    NaN
# 5492            Puya            laxa               NaN          NaN    NaN
# 5493         Hechtia   guatemalensis               NaN          NaN    NaN
# 5494        Catopsis       micrantha               NaN          NaN    NaN
# 5495        Guzmania     desautelsii               NaN          NaN    NaN
# 5496        Guzmania       sanguinea  brevipedicellata          NaN    NaN
# 5497        Guzmania         musaica          concolor          NaN    NaN
# 5498        Guzmania      circinnata               NaN          NaN    NaN
# 5499        Guzmania       glomerata               NaN          NaN    NaN
# 5500        Guzmania      multiflora               NaN          NaN    NaN
# 5501      Tillandsia        cretacea               NaN          NaN    NaN
# 5502      Tillandsia        deppeana               NaN          NaN    NaN
# 5503         Vriesea         ospinae           ospinae          NaN    NaN
# 5504         Vriesea        monstrum               NaN          NaN    NaN
# 5505        Werauhia       latissima               NaN          NaN    NaN
# 5506        Werauhia           jenii               NaN          NaN    NaN
# 5507        Werauhia         lutheri               NaN          NaN    NaN
# 5508        Werauhia       millennia               NaN          NaN    NaN
# 5509        Werauhia   sanguinolenta               NaN          NaN    NaN
# 5510        Werauhia      kupperiana               NaN          NaN    NaN
# 5511        Werauhia        capitata               NaN          NaN    NaN
# 5512        Werauhia         vittata               NaN          NaN    NaN
# 5513        Werauhia      paniculata               NaN          NaN    NaN
# 5514        Werauhia              sp               NaN          NaN    NaN
# 5515        Guzmania     monostachia       monostachia          NaN    NaN
# 5516         Vriesea      barclayana        barclayana          NaN    NaN
# 5517         Vriesea       espinosae               NaN          NaN    NaN
# 5518      Tillandsia        flexuosa               NaN          NaN    NaN
# 5519      Tillandsia         bulbosa               NaN          NaN    NaN
# 5520      Tillandsia        elongata      subimbricata          NaN    NaN
#
#       FM_DM_sd          ...            transpiration_ratio  avg_elevation_m  \
# 0          0.5          ...                            NaN              NaN
# 1          0.9          ...                            NaN              NaN
# 2          0.2          ...                            NaN              NaN
# 3          0.2          ...                            NaN              NaN
# 4          0.2          ...                            NaN              NaN
# 5          0.2          ...                            NaN              NaN
# 6          0.5          ...                            NaN              NaN
# 7          0.3          ...                            NaN              NaN
# 8          0.3          ...                            NaN              NaN
# 9          0.3          ...                            NaN              NaN
# 10         0.2          ...                            NaN              NaN
# 11         0.8          ...                            NaN              NaN
# 12         0.2          ...                            NaN              NaN
# 13         0.3          ...                            NaN              NaN
# 14         0.2          ...                            NaN              NaN
# 15         0.2          ...                            NaN              NaN
# 16         0.1          ...                            NaN              NaN
# 17         0.8          ...                            NaN              NaN
# 18         0.1          ...                            NaN              NaN
# 19         0.4          ...                            NaN              NaN
# 20         0.6          ...                            NaN              NaN
# 21         0.3          ...                            NaN              NaN
# 22         0.2          ...                            NaN              NaN
# 23         0.2          ...                            NaN              NaN
# 24         NaN          ...                            NaN              NaN
# 25         0.2          ...                            NaN              NaN
# 26         1.9          ...                            NaN              NaN
# 27         0.5          ...                            NaN              NaN
# 28         0.4          ...                            NaN              NaN
# 29         0.5          ...                            NaN              NaN
# ...        ...          ...                            ...              ...
# 5491       NaN          ...                            NaN              NaN
# 5492       NaN          ...                            NaN              NaN
# 5493       NaN          ...                            NaN              NaN
# 5494       NaN          ...                            NaN              NaN
# 5495       NaN          ...                            NaN              NaN
# 5496       NaN          ...                            NaN              NaN
# 5497       NaN          ...                            NaN              NaN
# 5498       NaN          ...                            NaN              NaN
# 5499       NaN          ...                            NaN              NaN
# 5500       NaN          ...                            NaN              NaN
# 5501       NaN          ...                            NaN              NaN
# 5502       NaN          ...                            NaN              NaN
# 5503       NaN          ...                            NaN              NaN
# 5504       NaN          ...                            NaN              NaN
# 5505       NaN          ...                            NaN              NaN
# 5506       NaN          ...                            NaN              NaN
# 5507       NaN          ...                            NaN              NaN
# 5508       NaN          ...                            NaN              NaN
# 5509       NaN          ...                            NaN              NaN
# 5510       NaN          ...                            NaN              NaN
# 5511       NaN          ...                            NaN              NaN
# 5512       NaN          ...                            NaN              NaN
# 5513       NaN          ...                            NaN              NaN
# 5514       NaN          ...                            NaN              NaN
# 5515       NaN          ...                            NaN              NaN
# 5516       NaN          ...                            NaN              NaN
# 5517       NaN          ...                            NaN              NaN
# 5518       NaN          ...                            NaN              NaN
# 5519       NaN          ...                            NaN              NaN
# 5520       NaN          ...                            NaN              NaN
#
#       LCCDM  SLAFM                            long_name  pct_night_C02  \
# 0       NaN    NaN                          Ada allenii            NaN
# 1       NaN    NaN              Ancipitia crocodiliceps            NaN
# 2       NaN    NaN                Arundina graminifolia            NaN
# 3       NaN    NaN                Aspasia epidendroides            NaN
# 4       NaN    NaN                  Aspasia principissa            NaN
# 5       NaN    NaN                   Brassavola acaulis            NaN
# 6       NaN    NaN                    Brassavola nodosa            NaN
# 7       NaN    NaN                    Brassia arcuigera            NaN
# 8       NaN    NaN                      Brassia caudata            NaN
# 9       NaN    NaN                    Brassia verrucosa            NaN
# 10      NaN    NaN                   Brenesia johnsonii            NaN
# 11      NaN    NaN                 Brenesia lappiformis            NaN
# 12      NaN    NaN                    Catasetum bicolor            NaN
# 13      NaN    NaN                  Catasetum maculatum            NaN
# 14      NaN    NaN               Catasetum viridiflavum            NaN
# 15      NaN    NaN                     Cattleya dowiana            NaN
# 16      NaN    NaN                Chelyorchis ampliatum            NaN
# 17      NaN    NaN               Cischweinfia dasyandra            NaN
# 18      NaN    NaN                 Cischweinfia pusilla            NaN
# 19      NaN    NaN                Clowesia warscewiczii            NaN
# 20      NaN    NaN               Cochleanthes aromatica            NaN
# 21      NaN    NaN              Coeliopsis hyacinthosma            NaN
# 22      NaN    NaN                Coryanthes hunteriana            NaN
# 23      NaN    NaN                     Cycnoches aureum            NaN
# 24      NaN    NaN                 Cycnoches guttulatum            NaN
# 25      NaN    NaN               Cycnoches warscewiczii            NaN
# 26      NaN    NaN          Cyrtochiloides ochmatochila            NaN
# 27      NaN    NaN                   Dichaea dammeriana            NaN
# 28      NaN    NaN               Dichaea fragrantissima            NaN
# 29      NaN    NaN                Dimerandra emarginata            NaN
# ...     ...    ...                                  ...            ...
# 5491    NaN    NaN                   Pitcairnia_arcuata            0.0
# 5492    NaN    NaN                            Puya_laxa           55.7
# 5493    NaN    NaN                Hechtia_guatemalensis           66.9
# 5494    NaN    NaN                   Catopsis_micrantha            0.0
# 5495    NaN    NaN                 Guzmania_desautelsii            0.0
# 5496    NaN    NaN  Guzmania_sanguinea_brevipedicellata            0.0
# 5497    NaN    NaN            Guzmania_musaica_concolor            0.0
# 5498    NaN    NaN                  Guzmania_circinnata            0.0
# 5499    NaN    NaN                   Guzmania_glomerata            0.0
# 5500    NaN    NaN                  Guzmania_multiflora            0.0
# 5501    NaN    NaN                  Tillandsia_cretacea            0.0
# 5502    NaN    NaN                  Tillandsia_deppeana            0.0
# 5503    NaN    NaN              Vriesea_ospinae_ospinae            0.0
# 5504    NaN    NaN                     Vriesea_monstrum            0.0
# 5505    NaN    NaN                   Werauhia_latissima            0.0
# 5506    NaN    NaN                       Werauhia_jenii            0.0
# 5507    NaN    NaN                     Werauhia_lutheri            0.0
# 5508    NaN    NaN                   Werauhia_millennia            0.0
# 5509    NaN    NaN               Werauhia_sanguinolenta            0.0
# 5510    NaN    NaN                  Werauhia_kupperiana            0.0
# 5511    NaN    NaN                    Werauhia_capitata            0.0
# 5512    NaN    NaN                     Werauhia_vittata            0.0
# 5513    NaN    NaN                  Werauhia_paniculata            0.0
# 5514    NaN    NaN                          Werauhia_sp            0.0
# 5515    NaN    NaN     Guzmania_monostachia_monostachia           10.0
# 5516    NaN    NaN        Vriesea_barclayana_barclayana           25.9
# 5517    NaN    NaN                    Vriesea_espinosae           62.6
# 5518    NaN    NaN                  Tillandsia_flexuosa           96.7
# 5519    NaN    NaN                   Tillandsia_bulbosa           97.2
# 5520    NaN    NaN     Tillandsia_elongata_subimbricata          100.0
#
#       H+_ev_mumol_g-1_DW H+_ev_mumol_g-1_DW_sd  H+_mo_mumol_g-1_DW  \
# 0                    NaN                   NaN                 NaN
# 1                    NaN                   NaN                 NaN
# 2                    NaN                   NaN                 NaN
# 3                    NaN                   NaN                 NaN
# 4                    NaN                   NaN                 NaN
# 5                    NaN                   NaN                 NaN
# 6                    NaN                   NaN                 NaN
# 7                    NaN                   NaN                 NaN
# 8                    NaN                   NaN                 NaN
# 9                    NaN                   NaN                 NaN
# 10                   NaN                   NaN                 NaN
# 11                   NaN                   NaN                 NaN
# 12                   NaN                   NaN                 NaN
# 13                   NaN                   NaN                 NaN
# 14                   NaN                   NaN                 NaN
# 15                   NaN                   NaN                 NaN
# 16                   NaN                   NaN                 NaN
# 17                   NaN                   NaN                 NaN
# 18                   NaN                   NaN                 NaN
# 19                   NaN                   NaN                 NaN
# 20                   NaN                   NaN                 NaN
# 21                   NaN                   NaN                 NaN
# 22                   NaN                   NaN                 NaN
# 23                   NaN                   NaN                 NaN
# 24                   NaN                   NaN                 NaN
# 25                   NaN                   NaN                 NaN
# 26                   NaN                   NaN                 NaN
# 27                   NaN                   NaN                 NaN
# 28                   NaN                   NaN                 NaN
# 29                   NaN                   NaN                 NaN
# ...                  ...                   ...                 ...
# 5491                0.12                  0.01                0.12
# 5492                0.18                  0.02                0.65
# 5493                0.58                  0.05                1.94
# 5494                0.12                  0.01                0.27
# 5495                0.09                  0.05                0.12
# 5496                0.56                  0.10                0.82
# 5497                0.11                  0.01                0.11
# 5498                0.22                  0.03                0.22
# 5499                0.24                  0.09                0.47
# 5500                0.68                  0.05                0.79
# 5501                0.41                  0.05                0.90
# 5502                0.11                  0.01                0.12
# 5503                0.21                  0.02                0.25
# 5504                0.18                  0.05                0.23
# 5505                0.24                  0.01                0.17
# 5506                0.31                  0.04                0.37
# 5507                0.11                  0.04                0.15
# 5508                0.12                  0.02                0.10
# 5509                0.19                  0.01                0.24
# 5510                0.08                  0.01                0.08
# 5511                0.15                  0.04                0.14
# 5512                0.15                  0.01                0.14
# 5513                0.24                  0.02                0.24
# 5514                0.13                  0.01                0.12
# 5515                0.91                  0.06                1.59
# 5516                0.39                  0.03                0.94
# 5517                0.09                  0.01                0.19
# 5518                0.13                  0.01                1.38
# 5519                0.07                  0.01                0.80
# 5520                0.40                  0.03                2.34
#
#       H+_mo_mumol_g-1_DW_sd
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# ...                     ...
# 5491                   0.01
# 5492                   0.04
# 5493                   0.20
# 5494                   0.08
# 5495                   0.04
# 5496                   0.25
# 5497                   0.01
# 5498                   0.02
# 5499                   0.08
# 5500                   0.09
# 5501                   0.15
# 5502                   0.01
# 5503                   0.02
# 5504                   0.03
# 5505                   0.03
# 5506                   0.03
# 5507                   0.01
# 5508                   0.01
# 5509                   0.01
# 5510                   0.01
# 5511                   0.04
# 5512                   0.01
# 5513                   0.01
# 5514                   0.01
# 5515                   0.27
# 5516                   0.06
# 5517                   0.01
# 5518                   0.26
# 5519                   0.12
# 5520                   0.17
#
# [5521 rows x 53 columns]

# %%
db_info(DF, plt_missingdata=True, labels=True)
# Out:
# The CAM database consists of:
# 	5521 observations,
# 	57 families,
# 	12 subfamiles,
# 	13 tribes,
# 	22 subtribes,
# 	434 genera, and
# 	3559 species from 61 publications.
# 0.812 of the data matrix is missing and
# 4028 observations have known photosynthetic pathways.

# %%
fig, (ax0, ax1) = plt.subplots(1, 2, figsize=(12,4))

ax0.hist(x=DF[DF['Pathway']=='CAM']['dC13'].dropna(), edgecolor='blue',
         linewidth=2, color='blue', alpha=0.5, bins=15)
ax0.hist(x=DF[DF['Pathway']=='C3']['dC13'].dropna(), edgecolor='orange', 
         linewidth=2, color='orange', alpha=0.5, bins=15)
ax0.hist(x=DF[DF['Pathway']=='C3-CAM']['dC13'].dropna(), edgecolor='red', 
         linewidth=2, color='red', alpha=0.5, bins=20)
ax0.hist(x=DF[DF['Pathway']=='C4']['dC13'].dropna(), edgecolor='green', 
         linewidth=2, color='green', alpha=0.5, bins=10)

ax1.hist(x=DF[DF['Pathway'].isin(['C3', 'C4', 'CAM', 'C3-CAM', 'C3-C4'])]['dC13'].dropna(), 
         fc=(1, 1, 1, 1), edgecolor='black', linewidth=2, alpha=1, bins=25)
ax1.hist(x=DF[DF['Pathway'].isnull()]['dC13'].dropna(), color='grey', alpha=0.25, bins=50)

orange_patch = mpatches.Patch(color='orange', alpha=0.5, label='C3', )
green_patch = mpatches.Patch(color='green', alpha=0.5, label='C4')
red_patch = mpatches.Patch(color='red', alpha=0.5, label='C3-CAM')
blue_patch = mpatches.Patch(color='blue', alpha=0.5, label='CAM')

ax0.legend(handles=[orange_patch, green_patch, red_patch, blue_patch], fontsize=12, frameon=True, )
ax0.set_xlim([-40, -5])
ax0.set_xlabel('$\delta$C$^{13}$', size=14)

grey_patch = mpatches.Patch(color='grey', alpha=0.5, label='Unknown pathway')
black_patch = mpatches.Patch(facecolor='white', edgecolor='black', linewidth=1, label='Known pathway')

ax1.legend(handles=[grey_patch, black_patch], fontsize=12, frameon=True, )
ax1.set_xlim([-40, -5])
ax1.set_xlabel('$\delta$C$^{13}$', size=14);

# %%
DF.loc[(DF['Pathway']=='CAM') & (DF['dC13']<-20)][metadata_keys+['Pathway', 'dC13', 'dH+_significance']]
# Out:
#                 Family        Subfamily       Tribe       Subtribe  \
# 10         Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 44         Orchidaceae   Epidendroideae  Calypsoeae      Laeliinae
# 45         Orchidaceae   Epidendroideae  Calypsoeae      Laeliinae
# 50         Orchidaceae   Epidendroideae  Calypsoeae      Laeliinae
# 52         Orchidaceae   Epidendroideae  Calypsoeae      Laeliinae
# 55         Orchidaceae   Epidendroideae  Calypsoeae      Laeliinae
# 76         Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 167        Orchidaceae   Epidendroideae  Calypsoeae      Bletiinae
# 433        Orchidaceae   Epidendroideae         NaN            NaN
# 434        Orchidaceae   Epidendroideae         NaN            NaN
# 751      Asparagacaeae              NaN         NaN            NaN
# 797       Bromeliaceae  Tillandsioideae         NaN            NaN
# 798       Bromeliaceae  Tillandsioideae         NaN            NaN
# 799       Bromeliaceae  Tillandsioideae         NaN            NaN
# 801       Bromeliaceae  Tillandsioideae         NaN            NaN
# 802       Bromeliaceae  Tillandsioideae         NaN            NaN
# 803       Bromeliaceae  Tillandsioideae         NaN            NaN
# 804       Bromeliaceae  Tillandsioideae         NaN            NaN
# 805       Bromeliaceae  Tillandsioideae         NaN            NaN
# 806       Bromeliaceae  Tillandsioideae         NaN            NaN
# 807       Bromeliaceae  Tillandsioideae         NaN            NaN
# 808       Bromeliaceae  Tillandsioideae         NaN            NaN
# 809       Bromeliaceae  Tillandsioideae         NaN            NaN
# 810       Bromeliaceae  Tillandsioideae         NaN            NaN
# 811       Bromeliaceae  Tillandsioideae         NaN            NaN
# 812       Bromeliaceae  Tillandsioideae         NaN            NaN
# 813       Bromeliaceae  Tillandsioideae         NaN            NaN
# 814       Bromeliaceae  Tillandsioideae         NaN            NaN
# 815       Bromeliaceae  Tillandsioideae         NaN            NaN
# 823       Bromeliaceae    Bromelioideae         NaN            NaN
# ...                ...              ...         ...            ...
# 5196       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5197       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5198       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5199       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5200       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5201       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5202       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5203       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5204       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5205       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5206       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5207       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5208       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5209       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5210       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5211       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5212       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5213       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5214       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5215       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5217       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5218       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5219       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5220       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5221       Orchidaceae   Epidendroideae  Cymbidieae     Oncidiinae
# 5319       Orchidaceae   Epidendroideae  Cymbidieae  Maxillariinae
# 5747        Isoetaceae              NaN         NaN            NaN
# 5748        Isoetaceae              NaN         NaN            NaN
# 5754        Isoetaceae              NaN         NaN            NaN
# 5762  Hydrocharitaceae              NaN         NaN            NaN
#
#             Genus          Species     Subspecies                  Source  \
# 10        Brassia        verrucosa    gireoudiana    Silvera et al (2005)
# 44     Epidendrum        coronatum            NaN    Silvera et al (2005)
# 45     Epidendrum       dentilobum            NaN    Silvera et al (2005)
# 50     Epidendrum        nocturnum            NaN    Silvera et al (2005)
# 52     Epidendrum           porpax            NaN    Silvera et al (2005)
# 55     Epidendrum       rousseauae            NaN    Silvera et al (2005)
# 76     Lockhartia            acuta            NaN    Silvera et al (2005)
# 167    Specklinia        barbulata            NaN    Silvera et al (2005)
# 433          Eria       eriaeoides            NaN  Earnshaw et al. (1987)
# 434          Eria       eriaeoides            NaN  Earnshaw et al. (1987)
# 751    Hesperaloe      campanulata            NaN      Heyduk et al. 2016
# 797       Vriesea            rubra            NaN   Griffiths et al. 1983
# 798       Vriesea        glutinosa            NaN   Griffiths et al. 1983
# 799       Vriesea    chrysostachys  chrysostachys   Griffiths et al. 1983
# 801       Vriesea        platynema      platynema   Griffiths et al. 1983
# 802       Vriesea        amazonica            NaN   Griffiths et al. 1983
# 803       Vriesea          ringens            NaN   Griffiths et al. 1983
# 804       Vriesea        broadwayi            NaN   Griffiths et al. 1983
# 805       Vriesea     splitgerberi            NaN   Griffiths et al. 1983
# 806       Vriesea     capituligera            NaN   Griffiths et al. 1983
# 807       Vriesea       johnstonii            NaN   Griffiths et al. 1983
# 808       Vriesea   didistiehoides            NaN   Griffiths et al. 1983
# 809       Vriesea          procera            NaN   Griffiths et al. 1983
# 810       Vriesea        splendens        formosa   Griffiths et al. 1983
# 811       Vriesea          simplex            NaN   Griffiths et al. 1983
# 812      Guzmania      megastachya            NaN   Griffiths et al. 1983
# 813      Guzmania      monostachia    monostachia   Griffiths et al. 1983
# 814      Guzmania        lingulata      lingulata   Griffiths et al. 1983
# 815      Guzmania        sanguinea      sanguinea   Griffiths et al. 1983
# 823      Bromelia         plumieri            NaN   Griffiths et al. 1983
# ...           ...              ...            ...                     ...
# 5196     Oncidium     bryolophotum            NaN    Silvera et al (2010)
# 5197     Oncidium      cariniferum            NaN    Silvera et al (2010)
# 5198     Oncidium     cheirophorum            NaN    Silvera et al (2010)
# 5199     Oncidium    dichromaticum            NaN    Silvera et al (2010)
# 5200     Oncidium          ensatum            NaN    Silvera et al (2010)
# 5201     Oncidium         exalatum            NaN    Silvera et al (2010)
# 5202     Oncidium         fuscatum            NaN    Silvera et al (2010)
# 5203     Oncidium      hymenanthum            NaN    Silvera et al (2010)
# 5204     Oncidium          imitans            NaN    Silvera et al (2010)
# 5205     Oncidium    integrilabris            NaN    Silvera et al (2010)
# 5206     Oncidium           isthmi            NaN    Silvera et al (2010)
# 5207     Oncidium     lineoligerum            NaN    Silvera et al (2010)
# 5208     Oncidium           luteum            NaN    Silvera et al (2010)
# 5209     Oncidium      macrobulbon            NaN    Silvera et al (2010)
# 5210     Oncidium        nebulosum            NaN    Silvera et al (2010)
# 5211     Oncidium     obryzatoides            NaN    Silvera et al (2010)
# 5212     Oncidium        panamense            NaN    Silvera et al (2010)
# 5213     Oncidium      parviflorum            NaN    Silvera et al (2010)
# 5214     Oncidium        pictoides            NaN    Silvera et al (2010)
# 5215     Oncidium  picturatissimum            NaN    Silvera et al (2010)
# 5217     Oncidium      punctulatum            NaN    Silvera et al (2010)
# 5218     Oncidium   schroederianum            NaN    Silvera et al (2010)
# 5219     Oncidium      stenobulbon            NaN    Silvera et al (2010)
# 5220     Oncidium     warszewiczii            NaN    Silvera et al (2010)
# 5221     Oncidium      zelenkoanum            NaN    Silvera et al (2010)
# 5319  Heterotaxis        maleolens            NaN    Silvera et al (2010)
# 5747      Isoetes         howellii            NaN                     NaN
# 5748      Isoetes         howellii            NaN                     NaN
# 5754      Isoetes        bolanderi            NaN                     NaN
# 5762  Vallisneria         Spiralis            NaN                     NaN
#
#      Pathway   dC13  dH+_significance
# 10       CAM -21.30               1.0
# 44       CAM -20.40               1.0
# 45       CAM -21.20               0.0
# 50       CAM -21.70               1.0
# 52       CAM -20.30               1.0
# 55       CAM -20.40               1.0
# 76       CAM -20.30               1.0
# 167      CAM -21.00               1.0
# 433      CAM -31.17               1.0
# 434      CAM -31.09               1.0
# 751      CAM -20.43               NaN
# 797      CAM -25.60               0.0
# 798      CAM -27.30               0.0
# 799      CAM -25.10               0.0
# 801      CAM -24.60               0.0
# 802      CAM -28.00               0.0
# 803      CAM -24.00               0.0
# 804      CAM -24.80               1.0
# 805      CAM -32.40               1.0
# 806      CAM -23.10               1.0
# 807      CAM -31.40               1.0
# 808      CAM -23.90               0.0
# 809      CAM -26.00               1.0
# 810      CAM -34.80               0.0
# 811      CAM -24.40               1.0
# 812      CAM -28.30               1.0
# 813      CAM -26.50               1.0
# 814      CAM -29.50               1.0
# 815      CAM -26.80               1.0
# 823      CAM -20.40               NaN
# ...      ...    ...               ...
# 5196     CAM -30.20               0.0
# 5197     CAM -27.70               0.0
# 5198     CAM -26.80               0.0
# 5199     CAM -29.70               0.0
# 5200     CAM -27.40               0.0
# 5201     CAM -28.80               0.0
# 5202     CAM -32.30               0.0
# 5203     CAM -28.20               0.0
# 5204     CAM -28.80               0.0
# 5205     CAM -27.20               0.0
# 5206     CAM -24.50               0.0
# 5207     CAM -28.30               0.0
# 5208     CAM -27.50               0.0
# 5209     CAM -28.80               0.0
# 5210     CAM -27.70               0.0
# 5211     CAM -28.60               0.0
# 5212     CAM -28.10               0.0
# 5213     CAM -31.90               0.0
# 5214     CAM -28.10               0.0
# 5215     CAM -29.70               0.0
# 5217     CAM -27.90               0.0
# 5218     CAM -28.10               0.0
# 5219     CAM -28.40               0.0
# 5220     CAM -27.00               0.0
# 5221     CAM -26.80               0.0
# 5319     CAM -23.90               0.0
# 5747     CAM -29.20               NaN
# 5748     CAM -24.30               NaN
# 5754     CAM -24.10               NaN
# 5762     CAM -31.50               NaN
#
# [457 rows x 11 columns]

# %%
modes(df=DF, key_cols=['Species'], value_col='Pathway', count_col='count')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-559d736c1850> in <module>()
# ----> 1 modes(df=DF, key_cols=['Species'], value_col='Pathway', count_col='count')
#
# TypeError: 'Series' object is not callable

# %%
DF['Pathway'].mode()
# Out:
# 0    CAM
# dtype: object

# %%
categorical_dict
# Out:
# {'Habit': <function __main__.<lambda>>,
#  'Pathway': <function __main__.<lambda>>,
#  'dH+_significance': <function __main__.<lambda>>}

# %%
DF
# Out:
#             Family        Subfamily       Tribe        Subtribe  \
# 1      Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 2      Orchidaceae              NaN         NaN             NaN
# 3      Orchidaceae   Epidendroideae  Arethuseae     Arethusinae
# 4      Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 5      Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 6      Orchidaceae   Epidendroideae  Calypsoeae       Laeliinae
# 7      Orchidaceae   Epidendroideae  Calypsoeae       Laeliinae
# 8      Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 9      Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 10     Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 11     Orchidaceae              NaN         NaN             NaN
# 12     Orchidaceae              NaN         NaN             NaN
# 13     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 14     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 16     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 17     Orchidaceae   Epidendroideae  Calypsoeae       Laeliinae
# 18     Orchidaceae              NaN         NaN             NaN
# 19     Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 20     Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 21     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 22     Orchidaceae   Epidendroideae  Cymbidieae   Zygopetalinae
# 23     Orchidaceae   Epidendroideae  Cymbidieae  Coeliopsidinae
# 24     Orchidaceae   Epidendroideae  Cymbidieae    Stanhopeinae
# 26     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 27     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 28     Orchidaceae   Epidendroideae  Cymbidieae     Catasetinae
# 29     Orchidaceae   Epidendroideae  Cymbidieae      Oncidiinae
# 30     Orchidaceae   Epidendroideae  Cymbidieae   Zygopetalinae
# 31     Orchidaceae   Epidendroideae  Cymbidieae   Zygopetalinae
# 33     Orchidaceae   Epidendroideae  Calypsoeae       Laeliinae
# ...            ...              ...         ...             ...
# 5826  Bromeliaceae  Pitcairnioideae         NaN             NaN
# 5827  Bromeliaceae  Pitcairnioideae         NaN             NaN
# 5828  Bromeliaceae  Pitcairnioideae         NaN             NaN
# 5829  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5830  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5831  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5832  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5833  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5834  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5835  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5836  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5837  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5838  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5839  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5840  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5841  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5842  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5843  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5844  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5845  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5846  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5847  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5848  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5849  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5850  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5851  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5852  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5853  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5854  Bromeliaceae  Tillandsioideae         NaN             NaN
# 5855  Bromeliaceae  Tillandsioideae         NaN             NaN
#
#                Genus         Species        Subspecies  BS_area_um2  FM_DM  \
# 1                Ada         allenii               NaN          NaN    8.1
# 2          Ancipitia   crocodiliceps               NaN          NaN    8.7
# 3           Arundina    graminifolia               NaN          NaN    3.5
# 4            Aspasia   epidendroides               NaN          NaN    5.3
# 5            Aspasia     principissa               NaN          NaN    4.5
# 6         Brassavola         acaulis               NaN          NaN   16.9
# 7         Brassavola          nodosa               NaN          NaN   12.5
# 8            Brassia       arcuigera               NaN          NaN    5.3
# 9            Brassia         caudata               NaN          NaN    5.5
# 10           Brassia       verrucosa       gireoudiana          NaN    6.5
# 11          Brenesia       johnsonii               NaN          NaN    8.4
# 12          Brenesia     lappiformis               NaN          NaN    8.8
# 13         Catasetum         bicolor               NaN          NaN    5.9
# 14         Catasetum       maculatum               NaN          NaN    5.0
# 16         Catasetum    viridiflavum               NaN          NaN    6.0
# 17          Cattleya         dowiana               NaN          NaN    9.9
# 18       Chelyorchis       ampliatum               NaN          NaN    7.6
# 19      Cischweinfia       dasyandra               NaN          NaN    6.1
# 20      Cischweinfia         pusilla               NaN          NaN    7.1
# 21          Clowesia    warscewiczii               NaN          NaN    5.8
# 22      Cochleanthes       aromatica               NaN          NaN    5.9
# 23        Coeliopsis    hyacinthosma               NaN          NaN    3.7
# 24        Coryanthes      hunteriana               NaN          NaN    5.8
# 26         Cycnoches          aureum               NaN          NaN    5.4
# 27         Cycnoches      guttulatum               NaN          NaN    NaN
# 28         Cycnoches    warscewiczii               NaN          NaN    4.8
# 29    Cyrtochiloides    ochmatochila               NaN          NaN    5.9
# 30           Dichaea      dammeriana               NaN          NaN    5.5
# 31           Dichaea  fragrantissima               NaN          NaN    6.2
# 33        Dimerandra      emarginata               NaN          NaN    5.3
# ...              ...             ...               ...          ...    ...
# 5826      Pitcairnia         arcuata               NaN          NaN    NaN
# 5827            Puya            laxa               NaN          NaN    NaN
# 5828         Hechtia   guatemalensis               NaN          NaN    NaN
# 5829        Catopsis       micrantha               NaN          NaN    NaN
# 5830        Guzmania     desautelsii               NaN          NaN    NaN
# 5831        Guzmania       sanguinea  brevipedicellata          NaN    NaN
# 5832        Guzmania         musaica          concolor          NaN    NaN
# 5833        Guzmania      circinnata               NaN          NaN    NaN
# 5834        Guzmania       glomerata               NaN          NaN    NaN
# 5835        Guzmania      multiflora               NaN          NaN    NaN
# 5836      Tillandsia        cretacea               NaN          NaN    NaN
# 5837      Tillandsia        deppeana               NaN          NaN    NaN
# 5838         Vriesea         ospinae           ospinae          NaN    NaN
# 5839         Vriesea        monstrum               NaN          NaN    NaN
# 5840        Werauhia       latissima               NaN          NaN    NaN
# 5841        Werauhia           jenii               NaN          NaN    NaN
# 5842        Werauhia         lutheri               NaN          NaN    NaN
# 5843        Werauhia       millennia               NaN          NaN    NaN
# 5844        Werauhia   sanguinolenta               NaN          NaN    NaN
# 5845        Werauhia      kupperiana               NaN          NaN    NaN
# 5846        Werauhia        capitata               NaN          NaN    NaN
# 5847        Werauhia         vittata               NaN          NaN    NaN
# 5848        Werauhia      paniculata               NaN          NaN    NaN
# 5849        Werauhia              sp               NaN          NaN    NaN
# 5850        Guzmania     monostachia       monostachia          NaN    NaN
# 5851         Vriesea      barclayana        barclayana          NaN    NaN
# 5852         Vriesea       espinosae               NaN          NaN    NaN
# 5853      Tillandsia        flexuosa               NaN          NaN    NaN
# 5854      Tillandsia         bulbosa               NaN          NaN    NaN
# 5855      Tillandsia        elongata      subimbricata          NaN    NaN
#
#       FM_DM_sd          ...            transpiration_ratio  avg_elevation_m  \
# 1          0.5          ...                            NaN              NaN
# 2          0.9          ...                            NaN              NaN
# 3          0.2          ...                            NaN              NaN
# 4          0.2          ...                            NaN              NaN
# 5          0.2          ...                            NaN              NaN
# 6          0.2          ...                            NaN              NaN
# 7          0.5          ...                            NaN              NaN
# 8          0.3          ...                            NaN              NaN
# 9          0.3          ...                            NaN              NaN
# 10         0.3          ...                            NaN              NaN
# 11         0.2          ...                            NaN              NaN
# 12         0.8          ...                            NaN              NaN
# 13         0.2          ...                            NaN              NaN
# 14         0.3          ...                            NaN              NaN
# 16         0.2          ...                            NaN              NaN
# 17         0.2          ...                            NaN              NaN
# 18         0.1          ...                            NaN              NaN
# 19         0.8          ...                            NaN              NaN
# 20         0.1          ...                            NaN              NaN
# 21         0.4          ...                            NaN              NaN
# 22         0.6          ...                            NaN              NaN
# 23         0.3          ...                            NaN              NaN
# 24         0.2          ...                            NaN              NaN
# 26         0.2          ...                            NaN              NaN
# 27         NaN          ...                            NaN              NaN
# 28         0.2          ...                            NaN              NaN
# 29         1.9          ...                            NaN              NaN
# 30         0.5          ...                            NaN              NaN
# 31         0.4          ...                            NaN              NaN
# 33         0.5          ...                            NaN              NaN
# ...        ...          ...                            ...              ...
# 5826       NaN          ...                            NaN              NaN
# 5827       NaN          ...                            NaN              NaN
# 5828       NaN          ...                            NaN              NaN
# 5829       NaN          ...                            NaN              NaN
# 5830       NaN          ...                            NaN              NaN
# 5831       NaN          ...                            NaN              NaN
# 5832       NaN          ...                            NaN              NaN
# 5833       NaN          ...                            NaN              NaN
# 5834       NaN          ...                            NaN              NaN
# 5835       NaN          ...                            NaN              NaN
# 5836       NaN          ...                            NaN              NaN
# 5837       NaN          ...                            NaN              NaN
# 5838       NaN          ...                            NaN              NaN
# 5839       NaN          ...                            NaN              NaN
# 5840       NaN          ...                            NaN              NaN
# 5841       NaN          ...                            NaN              NaN
# 5842       NaN          ...                            NaN              NaN
# 5843       NaN          ...                            NaN              NaN
# 5844       NaN          ...                            NaN              NaN
# 5845       NaN          ...                            NaN              NaN
# 5846       NaN          ...                            NaN              NaN
# 5847       NaN          ...                            NaN              NaN
# 5848       NaN          ...                            NaN              NaN
# 5849       NaN          ...                            NaN              NaN
# 5850       NaN          ...                            NaN              NaN
# 5851       NaN          ...                            NaN              NaN
# 5852       NaN          ...                            NaN              NaN
# 5853       NaN          ...                            NaN              NaN
# 5854       NaN          ...                            NaN              NaN
# 5855       NaN          ...                            NaN              NaN
#
#       LCCDM  SLAFM                            long_name  pct_night_C02  \
# 1       NaN    NaN                          Ada allenii            NaN
# 2       NaN    NaN              Ancipitia crocodiliceps            NaN
# 3       NaN    NaN                Arundina graminifolia            NaN
# 4       NaN    NaN                Aspasia epidendroides            NaN
# 5       NaN    NaN                  Aspasia principissa            NaN
# 6       NaN    NaN                   Brassavola acaulis            NaN
# 7       NaN    NaN                    Brassavola nodosa            NaN
# 8       NaN    NaN                    Brassia arcuigera            NaN
# 9       NaN    NaN                      Brassia caudata            NaN
# 10      NaN    NaN                    Brassia verrucosa            NaN
# 11      NaN    NaN                   Brenesia johnsonii            NaN
# 12      NaN    NaN                 Brenesia lappiformis            NaN
# 13      NaN    NaN                    Catasetum bicolor            NaN
# 14      NaN    NaN                  Catasetum maculatum            NaN
# 16      NaN    NaN               Catasetum viridiflavum            NaN
# 17      NaN    NaN                     Cattleya dowiana            NaN
# 18      NaN    NaN                Chelyorchis ampliatum            NaN
# 19      NaN    NaN               Cischweinfia dasyandra            NaN
# 20      NaN    NaN                 Cischweinfia pusilla            NaN
# 21      NaN    NaN                Clowesia warscewiczii            NaN
# 22      NaN    NaN               Cochleanthes aromatica            NaN
# 23      NaN    NaN              Coeliopsis hyacinthosma            NaN
# 24      NaN    NaN                Coryanthes hunteriana            NaN
# 26      NaN    NaN                     Cycnoches aureum            NaN
# 27      NaN    NaN                 Cycnoches guttulatum            NaN
# 28      NaN    NaN               Cycnoches warscewiczii            NaN
# 29      NaN    NaN          Cyrtochiloides ochmatochila            NaN
# 30      NaN    NaN                   Dichaea dammeriana            NaN
# 31      NaN    NaN               Dichaea fragrantissima            NaN
# 33      NaN    NaN                Dimerandra emarginata            NaN
# ...     ...    ...                                  ...            ...
# 5826    NaN    NaN                   Pitcairnia_arcuata            0.0
# 5827    NaN    NaN                            Puya_laxa           55.7
# 5828    NaN    NaN                Hechtia_guatemalensis           66.9
# 5829    NaN    NaN                   Catopsis_micrantha            0.0
# 5830    NaN    NaN                 Guzmania_desautelsii            0.0
# 5831    NaN    NaN  Guzmania_sanguinea_brevipedicellata            0.0
# 5832    NaN    NaN            Guzmania_musaica_concolor            0.0
# 5833    NaN    NaN                  Guzmania_circinnata            0.0
# 5834    NaN    NaN                   Guzmania_glomerata            0.0
# 5835    NaN    NaN                  Guzmania_multiflora            0.0
# 5836    NaN    NaN                  Tillandsia_cretacea            0.0
# 5837    NaN    NaN                  Tillandsia_deppeana            0.0
# 5838    NaN    NaN              Vriesea_ospinae_ospinae            0.0
# 5839    NaN    NaN                     Vriesea_monstrum            0.0
# 5840    NaN    NaN                   Werauhia_latissima            0.0
# 5841    NaN    NaN                       Werauhia_jenii            0.0
# 5842    NaN    NaN                     Werauhia_lutheri            0.0
# 5843    NaN    NaN                   Werauhia_millennia            0.0
# 5844    NaN    NaN               Werauhia_sanguinolenta            0.0
# 5845    NaN    NaN                  Werauhia_kupperiana            0.0
# 5846    NaN    NaN                    Werauhia_capitata            0.0
# 5847    NaN    NaN                     Werauhia_vittata            0.0
# 5848    NaN    NaN                  Werauhia_paniculata            0.0
# 5849    NaN    NaN                          Werauhia_sp            0.0
# 5850    NaN    NaN     Guzmania_monostachia_monostachia           10.0
# 5851    NaN    NaN        Vriesea_barclayana_barclayana           25.9
# 5852    NaN    NaN                    Vriesea_espinosae           62.6
# 5853    NaN    NaN                  Tillandsia_flexuosa           96.7
# 5854    NaN    NaN                   Tillandsia_bulbosa           97.2
# 5855    NaN    NaN     Tillandsia_elongata_subimbricata          100.0
#
#       H+_ev_mumol_g-1_DW H+_ev_mumol_g-1_DW_sd  H+_mo_mumol_g-1_DW  \
# 1                    NaN                   NaN                 NaN
# 2                    NaN                   NaN                 NaN
# 3                    NaN                   NaN                 NaN
# 4                    NaN                   NaN                 NaN
# 5                    NaN                   NaN                 NaN
# 6                    NaN                   NaN                 NaN
# 7                    NaN                   NaN                 NaN
# 8                    NaN                   NaN                 NaN
# 9                    NaN                   NaN                 NaN
# 10                   NaN                   NaN                 NaN
# 11                   NaN                   NaN                 NaN
# 12                   NaN                   NaN                 NaN
# 13                   NaN                   NaN                 NaN
# 14                   NaN                   NaN                 NaN
# 16                   NaN                   NaN                 NaN
# 17                   NaN                   NaN                 NaN
# 18                   NaN                   NaN                 NaN
# 19                   NaN                   NaN                 NaN
# 20                   NaN                   NaN                 NaN
# 21                   NaN                   NaN                 NaN
# 22                   NaN                   NaN                 NaN
# 23                   NaN                   NaN                 NaN
# 24                   NaN                   NaN                 NaN
# 26                   NaN                   NaN                 NaN
# 27                   NaN                   NaN                 NaN
# 28                   NaN                   NaN                 NaN
# 29                   NaN                   NaN                 NaN
# 30                   NaN                   NaN                 NaN
# 31                   NaN                   NaN                 NaN
# 33                   NaN                   NaN                 NaN
# ...                  ...                   ...                 ...
# 5826                0.12                  0.01                0.12
# 5827                0.18                  0.02                0.65
# 5828                0.58                  0.05                1.94
# 5829                0.12                  0.01                0.27
# 5830                0.09                  0.05                0.12
# 5831                0.56                  0.10                0.82
# 5832                0.11                  0.01                0.11
# 5833                0.22                  0.03                0.22
# 5834                0.24                  0.09                0.47
# 5835                0.68                  0.05                0.79
# 5836                0.41                  0.05                0.90
# 5837                0.11                  0.01                0.12
# 5838                0.21                  0.02                0.25
# 5839                0.18                  0.05                0.23
# 5840                0.24                  0.01                0.17
# 5841                0.31                  0.04                0.37
# 5842                0.11                  0.04                0.15
# 5843                0.12                  0.02                0.10
# 5844                0.19                  0.01                0.24
# 5845                0.08                  0.01                0.08
# 5846                0.15                  0.04                0.14
# 5847                0.15                  0.01                0.14
# 5848                0.24                  0.02                0.24
# 5849                0.13                  0.01                0.12
# 5850                0.91                  0.06                1.59
# 5851                0.39                  0.03                0.94
# 5852                0.09                  0.01                0.19
# 5853                0.13                  0.01                1.38
# 5854                0.07                  0.01                0.80
# 5855                0.40                  0.03                2.34
#
#       H+_mo_mumol_g-1_DW_sd
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# 30                      NaN
# 31                      NaN
# 33                      NaN
# ...                     ...
# 5826                   0.01
# 5827                   0.04
# 5828                   0.20
# 5829                   0.08
# 5830                   0.04
# 5831                   0.25
# 5832                   0.01
# 5833                   0.02
# 5834                   0.08
# 5835                   0.09
# 5836                   0.15
# 5837                   0.01
# 5838                   0.02
# 5839                   0.03
# 5840                   0.03
# 5841                   0.03
# 5842                   0.01
# 5843                   0.01
# 5844                   0.01
# 5845                   0.01
# 5846                   0.04
# 5847                   0.01
# 5848                   0.01
# 5849                   0.01
# 5850                   0.27
# 5851                   0.06
# 5852                   0.01
# 5853                   0.26
# 5854                   0.12
# 5855                   0.17
#
# [5521 rows x 53 columns]

# %%
series
# Out:
# Pathway
# C3       0        C3
# C3-CAM   0    C3-CAM
# C4       0        C4
# CAM      0       CAM
# Name: Pathway, dtype: object

# %%
cam_avgs = cam_db.groupby('long_name').mean().reset_index()
cam_avgs = cam_avgs[[col for col in cam_avgs.columns if '_sd' not in col]]
print(len(cam_avgs))
cam_avgs.head()

# %%
cam_avgs['Family'] = [list(cam_db[cam_db['long_name']==species]['Family'])[0] for species in cam_avgs['long_name']]
cam_avgs['Subfamily'] = [list(cam_db[cam_db['long_name']==species]['Subfamily'])[0] for species in cam_avgs['long_name']]
cam_avgs['Tribe'] = [list(cam_db[cam_db['long_name']==species]['Tribe'])[0] for species in cam_avgs['long_name']]
cam_avgs['Subtribe'] = [list(cam_db[cam_db['long_name']==species]['Subtribe'])[0] for species in cam_avgs['long_name']]
cam_avgs['Genus'] = [species.split()[0] for species in cam_avgs['long_name']]

# %%
cam_avgs.merge(cam_db[['long_name', 'Pathway']], on='long_name').drop_duplicates().head()

# %%
# Get list of numerical features
filling = []
filling.append([cam_avgs[col].count() for col in cam_avgs.columns])
    
numerical = list(set(cam_avgs.columns)-set(['long_name', 'Genus', 'Subtribe', 'Tribe', 'Subfamily', 'Family']))

for genus in cam_avgs['Genus'].unique():
    # Get mean vector for each genus
    mu = cam_avgs[cam_avgs['Genus']==genus].mean()
    # Tranform to dictionary for fillna
    values = dict(zip(list(mu.keys()), list(mu.values)))
    # fillna genus by genus
    cam_avgs[cam_avgs['Genus']==genus] = cam_avgs[cam_avgs['Genus']==genus].fillna(value=values)

filling.append([cam_avgs[col].count() for col in cam_avgs.columns])
    
for subtribe in cam_avgs['Subtribe'].unique():
    mu = cam_avgs[cam_avgs['Subtribe']==subtribe].mean()
    values = dict(zip(list(mu.keys()), list(mu.values)))
    cam_avgs[cam_avgs['Subtribe']==subtribe] = cam_avgs[cam_avgs['Subtribe']==subtribe].fillna(value=values)
filling.append([cam_avgs[col].count() for col in cam_avgs.columns])
    
for tribe in cam_avgs['Tribe'].unique():
    mu = cam_avgs[cam_avgs['Tribe']==tribe].mean()
    values = dict(zip(list(mu.keys()), list(mu.values)))
    cam_avgs[cam_avgs['Tribe']==tribe] = cam_avgs[cam_avgs['Tribe']==tribe].fillna(value=values)    
filling.append([cam_avgs[col].count() for col in cam_avgs.columns])

for subfamily in cam_avgs['Subfamily'].unique():
    mu = cam_avgs[cam_avgs['Subfamily']==subfamily].mean()
    values = dict(zip(list(mu.keys()), list(mu.values)))
    cam_avgs[cam_avgs['Subfamily']==subfamily] = cam_avgs[cam_avgs['Subfamily']==subfamily].fillna(value=values)
filling.append([cam_avgs[col].count() for col in cam_avgs.columns])

for family in cam_avgs['Family'].unique():
    mu = cam_avgs[cam_avgs['Family']==family].mean()
    values = dict(zip(list(mu.keys()), list(mu.values)))
    cam_avgs[cam_avgs['Family']==family] = cam_avgs[cam_avgs['Family']==family].fillna(value=values)
filling.append([cam_avgs[col].count() for col in cam_avgs.columns])

# %%
fig, ax = plt.subplots(figsize=(16,6))

for i in filling:
    plt.plot(i)

# %%
msno.matrix(cam_avgs);

# %%
cam_avgs.describe()

# %%
# Drop features with less than 1000 entries
cam_avgs.dropna(axis=1, thresh=999, inplace=True)
numerical = list(set(cam_avgs.columns)-set(['Family', 'Subfamily', 'Tribe', 'Subtribe', 'Genus', 'long_name']))

# %%
# Log transform (except dC13)
cam_log_avgs = cam_avgs[numerical].apply(np.log)
cam_log_avgs['long_name'] = cam_avgs['long_name']
cam_log_avgs['dC13'] = cam_avgs['dC13']

# %%
pd.Series(['a', 'a','a','b'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-bf9926b3aed8> in <module>()
# ----> 1 pd.Series(['a', 'a','a','b']).mean()
#
# /Users/iangilman/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    6195                                       skipna=skipna)
#    6196         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 6197                             numeric_only=numeric_only)
#    6198
#    6199     return set_function_name(stat_func, name, cls)
#
# /Users/iangilman/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    2379                                           'numeric_only.'.format(name))
#    2380             with np.errstate(all='ignore'):
# -> 2381                 return op(delegate, skipna=skipna, **kwds)
#    2382
#    2383         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# /Users/iangilman/anaconda2/lib/python2.7/site-packages/pandas/core/nanops.pyc in _f(*args, **kwargs)
#      60             try:
#      61                 with np.errstate(invalid='ignore'):
# ---> 62                     return f(*args, **kwargs)
#      63             except ValueError as e:
#      64                 # we want to transform an object array
#
# /Users/iangilman/anaconda2/lib/python2.7/site-packages/pandas/core/nanops.pyc in f(values, axis, skipna, **kwds)
#     120             except Exception:
#     121                 try:
# --> 122                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     123                 except ValueError as e:
#     124                     # we want to transform an object array
#
# /Users/iangilman/anaconda2/lib/python2.7/site-packages/pandas/core/nanops.pyc in nanmean(values, axis, skipna)
#     310         dtype_count = dtype
#     311     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 312     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     313
#     314     if axis is not None and getattr(the_sum, 'ndim', False):
#
# /Users/iangilman/anaconda2/lib/python2.7/site-packages/pandas/core/nanops.pyc in _ensure_numeric(x)
#     771                 x = complex(x)
#     772             except Exception:
# --> 773                 raise TypeError('Could not convert %s to numeric' % str(x))
#     774     return x
#     775
#
# TypeError: Could not convert aaab to numeric

# %%
cam_log_avgs.head()

# %%
fig, ax = plt.subplots(figsize=(12,8))
cam_log_avgs.boxplot(ax=ax)

ax.set_xticklabels(cam_log_avgs.columns, rotation=60);

# %%
msno.matrix(df=cam_log_avgs);

# %%
cam_log_reduced = cam_log_avgs.dropna(axis=1, thresh=2000)
cam_log_reduced.dropna(inplace=True)

# %%
msno.matrix(df=cam_log_reduced);

# %%
pd.isnull(cam_log_reduced).sum()

# %%
# Compute the correlation matrix
log_cam_avgs_corr = cam_log_reduced.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(log_cam_avgs_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(log_cam_avgs_corr, annot=True,mask=mask, cmap="RdBu_r", vmax=.3, center=0,
            square=True, linewidths=.5, cbar=False);

# %%
fig, ax = plt.subplots(figsize=(8,4))
cam_log_reduced.boxplot(ax=ax)

ax.set_xticklabels(cam_log_reduced.columns, rotation=60);

# %%
for col in cam_log_reduced.columns:
    print col, len(cam_log_reduced[col].unique())
